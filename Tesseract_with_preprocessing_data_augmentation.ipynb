# %%
import os
from PIL import Image, ImageFilter
import numpy as np
import random

# Binarization
def binarize_image(image):
    img = image.convert('L')  # Convert image to grayscale
    # Binarize using a threshold
    threshold = 128
    binary_img = img.point(lambda p: 255 if p > threshold else 0)
    return binary_img

# Deskewing
def deskew_image(image):
    # Convert to NumPy array
    img_array = np.array(image)

    # Find the coordinates of the black (non-background) pixels
    coords = np.column_stack(np.where(img_array == 0))
    if len(coords) == 0:
        return image  # If there are no black pixels, return the original image

    # Calculate the angle of skew
    angle = np.rad2deg(np.arctan2(coords[:, 1].mean() - img_array.shape[0] / 2, coords[:, 0].mean() - img_array.shape[1] / 2))

    if angle < -45:
        angle = -(90 + angle)
    else:
        angle = -angle

    # Rotate the image
    pil_image = image.rotate(angle, expand=True)  # Use PIL to rotate
    return pil_image

# Noise removal
def remove_noise(image):
    # Apply a Gaussian blur to reduce noise
    denoised_image = image.filter(ImageFilter.GaussianBlur(radius=1))
    return denoised_image

# Preprocess an image
def preprocess_image(img):
    if isinstance(img, str):  # If the input is a file path, open the image
        img = Image.open(img)

    # Binarize the image (assuming this function is defined)
    binary_img = binarize_image(img)

    # Deskew the image (assuming this function is defined)
    deskewed_img = deskew_image(binary_img)

    # Resize the image to a fixed size (for example 1024x1024)
    resized_img = deskewed_img.resize((1024, 1024))

    return resized_img

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
from PIL import Image, ImageEnhance, ImageFilter
import numpy as np
import random

# Load and preprocess data
def load_washington_data(images_folder, transcription_file):
    images = []
    transcriptions = []

    # Load images as PIL Image objects
    for filename in os.listdir(images_folder):
        if filename.endswith('.png'):
            img_path = os.path.join(images_folder, filename)
            img = Image.open(img_path)  # Open image using PIL
            images.append(img)

    # Load transcriptions
    with open(transcription_file, 'r') as f:
        transcriptions = [line.strip() for line in f.readlines()]

    return images, transcriptions

import random
from PIL import Image, ImageEnhance
from torchvision import transforms

# Define the AdvancedAugmentation class
class AdvancedAugmentation:
    def __init__(self):
        self.transforms = transforms.Compose([
            transforms.RandomRotation(15),  # Rotate images randomly within a 15-degree range
            transforms.RandomHorizontalFlip(),
            transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2),  # Randomly change brightness, contrast, saturation, and hue
            transforms.RandomAffine(translate=(0.1, 0.1), degrees=10, shear=10)  # Random affine transformations
        ])

    def __call__(self, img):
        return self.transforms(img)

# Function to augment images
def augment_images_with_labels(images, transcriptions):
    augmented_images = []
    augmented_transcriptions = []

    # Initialize the advanced augmentation
    augmentation = AdvancedAugmentation()

    for img, transcription in zip(images, transcriptions):
        augmented = augmentation(img)  # Apply the advanced augmentation to the image
        augmented_images.append(augmented)
        augmented_transcriptions.append(transcription)  # Keep the original transcription for augmented image

    return augmented_images, augmented_transcriptions



# Split the data into train, validation, and test sets
def split_data(images, transcriptions, train_ratio=0.7, val_ratio=0.15):
    total_size = len(images)
    indices = list(range(total_size))
    random.shuffle(indices)

    train_size = int(total_size * train_ratio)
    val_size = int(total_size * val_ratio)

    train_indices = indices[:train_size]
    val_indices = indices[train_size:train_size + val_size]
    test_indices = indices[train_size + val_size:]

    train_images = [images[i] for i in train_indices]
    train_transcriptions = [transcriptions[i] for i in train_indices]

    val_images = [images[i] for i in val_indices]
    val_transcriptions = [transcriptions[i] for i in val_indices]

    test_images = [images[i] for i in test_indices]
    test_transcriptions = [transcriptions[i] for i in test_indices]

    return (train_images, train_transcriptions), (val_images, val_transcriptions), (test_images, test_transcriptions)

# %%
import os
from PIL import Image
import numpy as np
import torch
import torch.nn as nn
import torchvision.transforms as transforms
from torchvision import models
from sklearn.model_selection import train_test_split

# Main workflow
images_folder = '/content/drive/My Drive/washingtondb-v1.0/data/line_images_normalized'
transcription_file = '/content/drive/My Drive/washingtondb-v1.0/ground_truth/transcription.txt'

# Load data
images, transcriptions = load_washington_data(images_folder, transcription_file)

# Preprocess images
preprocessed_images = [preprocess_image(img) for img in images]

# Augment data
augmented_images, augmented_transcriptions = augment_images_with_labels(preprocessed_images, transcriptions)

# Combine original and augmented data
all_images = preprocessed_images + augmented_images
all_transcriptions = transcriptions + augmented_transcriptions  # Keep the same length of transcriptions

# Split data
(train_images, train_transcriptions), (val_images, val_transcriptions), (test_images, test_transcriptions) = split_data(all_images, all_transcriptions)

# %%
print(len(all_images))
# Out:
# 1312

# %%
# !pip install pytesseract
# Out:
# Requirement already satisfied: pytesseract in /usr/local/lib/python3.10/dist-packages (0.3.13)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (24.2)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (11.0.0)

# %%
# !apt-get update
# !apt-get install tesseract-ocr
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Get:7 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 129 kB in 1s (114 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 57 not upgraded.

# %%
import pytesseract
custom_config = r'--oem 3 --psm 6'
pytesseract.pytesseract.tesseract_cmd = r'tesseract'

# %%
# !pip install jiwer
# Out:
# Requirement already satisfied: jiwer in /usr/local/lib/python3.10/dist-packages (3.0.5)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from jiwer) (8.1.7)
# Requirement already satisfied: rapidfuzz<4,>=3 in /usr/local/lib/python3.10/dist-packages (from jiwer) (3.10.1)

# %%
# Function to extract text from the image line by line

# Function to clean the extracted text
def preprocess_extracted_text(extracted_text):
    extracted_text = extracted_text.replace('|', ' ').replace('-', '')
    return extracted_text.strip()

# %%
import pytesseract
from PIL import Image
from jiwer import wer

# Assuming all_images contains PIL.Image objects, not file names
# and ground_truth_lines contains the corresponding ground truth text

# Function to clean and preprocess ground truth lines
def preprocess_ground_truth(line):
    # Remove line numbers (assuming they are at the start and followed by a space)
    line = line.split(' ', 1)[-1] if ' ' in line else line
    # Replace "|" with spaces
    line = line.replace('|', ' ')
    # Remove dashes
    line = line.replace('-', '')
    return line.strip()

# Process each image in memory and calculate WER
for image, ground_truth in zip(all_images, all_transcriptions):
    # Ensure `image` is a PIL.Image object
    # Perform OCR on the image in memory using pytesseract
    extracted_text = pytesseract.image_to_string(image, config=custom_config)

    # Preprocess the extracted text to ensure it's on one line
    extracted_text = ' '.join(extracted_text.splitlines()).strip()

    # Preprocess the ground truth
    ground_truth = preprocess_ground_truth(ground_truth)

    # Calculate and print WER
    error_rate = wer(ground_truth, extracted_text)
    print(f"WER: {error_rate:.2%}")
    print(f"Extracted: {extracted_text}")
    print(f"Ground Truth: {ground_truth}\n")
# Out:
# Streaming output truncated to the last 5000 lines.
# WER: 211.11%
# Extracted: a 8 . ye ‘ gd  et 5 a | AS ay oa a AS S a ‘ A
# Ground Truth: is sufficient to Break the best Officer that ever
#
# WER: 100.00%
# Extracted: cv ag re
# Ground Truth: bore a Commis_ssions_pt
#
# WER: 316.67%
# Extracted: AS t AY cs ‘Sy ay nl e a eS 9 a ™~ ry S AS AP) \ at
# Ground Truth: s_2s_7s_2s_pt Letterss_cm Orders and Instructionss_pt October
#
# WER: 200.00%
# Extracted: Ss a a \ e ) & 4 NK Co of ¥ “ ' ~ ’ ee
# Ground Truth: s_2s_8ths_pt To Captain Peter Hoggs_cm of the Virginia
#
# WER: 400.00%
# Extracted: {/ 3 ry ra
# Ground Truth: Regiments_pt
#
# WER: 100.00%
# Extracted:
# Ground Truth: Sirs_cm
#
# WER: 162.50%
# Extracted: 4 | a be y y 3 \ ' ' y roy 3
# Ground Truth: I received yours of the s_6ths_pt of Octos_mi
#
# WER: 114.29%
# Extracted: re kg Ng NJ . S re yS
# Ground Truth: bers_cm inclosing the Returns of your Companys_cm
#
# WER: 114.29%
# Extracted: r Y Cd rs aX) ee "4 eo
# Ground Truth: only this days_pt Ferguson was sent after
#
# WER: 90.91%
# Extracted: VS ‘gy WE a oy 3 ey ae a
# Ground Truth: yous_cm but falling ills_cm by a Sore on his arms_cm was
#
# WER: 175.00%
# Extracted: & nS rR rN nea Ks mS \ = ae | \ he .
# Ground Truth: ordered to halt heres_cm where he now remains
#
# WER: 171.43%
# Extracted: SS rs SS xs oo “~ oe ; os GS | ~
# Ground Truth: unfit for Dutys_qo therefore I have sent
#
# WER: 142.86%
# Extracted: aN & a ne we ie oS) tN oe 2"
# Ground Truth: in his rooms_pt Sergeant Wilper has received
#
# WER: 216.67%
# Extracted: xs ‘9h OA a) Ry aw an ° \~ oy eu a) ~~
# Ground Truth: from Fort Cumberland and this place
#
# WER: 142.86%
# Extracted: ra a ~ w\ | : AS ts } re
# Ground Truth: Arms and Clothing to complete your Compas_mi
#
# WER: 185.71%
# Extracted: RY iS ay Ss wg w\Y * = os S r wh Ss
# Ground Truth: ny to the Establishments_pt He has enlisted
#
# WER: 100.00%
# Extracted: we ey iy at & SS b
# Ground Truth: three men on his marchs_cm and I have ors_mi
#
# WER: 142.86%
# Extracted: xh “ Sy % So . cs Sy q ay
# Ground Truth: dered Ensign Flemings_cm with eight otherss_cm to
#
# WER: 120.00%
# Extracted: ys yg * | ~ : a  SS  x rs '  oN '
# Ground Truth: join yous_sq he being a Surgeons_cm he is desired to
#
# WER: 162.50%
# Extracted: aN a S . = XR \ ss ne ok S ~ ns)
# Ground Truth: take care of your Companys_sq for which he
#
# WER: 112.50%
# Extracted: \ ys -& \ RS & A = gr
# Ground Truth: will be alloweds_pt You must use your best
#
# WER: 100.00%
# Extracted: V4 KS y
# Ground Truth: endeavours to secure your provisionss_cm and do
#
# WER: 118.18%
# Extracted: ~  < & rs y xe e SN « < SS 2 aN
# Ground Truth: with it as you see most needful s_qos_mi It is impos_ssis_mi
#
# WER: 100.00%
# Extracted: y 4 oy nN ‘4
# Ground Truth: ble I can direct about it at this distances_cm
#
# WER: 100.00%
# Extracted: a Re y e re ry a @
# Ground Truth: properlys_pt As we have contracted for a
#
# WER: 142.86%
# Extracted: y Re we ‘S SS re ra Rk Y &
# Ground Truth: large quantity of Beef alreadys_cm you are
#
# WER: 125.00%
# Extracted: S&S ry eo © es a nog & SS &S
# Ground Truth: desired to engage no more than what will
#
# WER: 100.00%
# Extracted: < G ys ¥ Sg
# Ground Truth: suffice for your own Companys_pt I shall
#
# WER: 187.50%
# Extracted: = oy ae < a > me od SE gL. > R < oo ao.
# Ground Truth: see that money is lodged with Mrs_pt Dick
#
# WER: 120.00%
# Extracted: 0 SN < ae *® rs as) cv st fk ws dy
# Ground Truth: for your use when I see hims_pt You are to
#
# WER: 100.00%
# Extracted: s \ Xd a we ra
# Ground Truth: see the usual stoppages from the mens
#
# WER: 112.50%
# Extracted: CS 4 ee oo : X gS ts fR
# Ground Truth: pay while they are in the Hospitals_cm to
#
# WER: 116.67%
# Extracted: ra Qs ~ eC Sg rs &
# Ground Truth: answer the expence of Nursess_cm s_etcs_pt
#
# WER: 100.00%
# Extracted: LS ya ye » ce y &, at
# Ground Truth: You must be very careful not to slip
#
# WER: 100.00%
# Extracted: Ro re » oe ng we ra
# Ground Truth: the opportunity of purchasing Grain for your
#
# WER: 116.67%
# Extracted: ye re yi Se Le ac g
# Ground Truth: Companys_cm that being your only dependance
#
# WER: 271.43%
# Extracted: om ~ 2  Pay  > a & << “oe om ch, > a a> << nae a & —_
# Ground Truth: Letterss_cm Orders and Instructionss_pt October s_1s_7s_5s_5s_pt s_2s_7s_3s_pt
#
# WER: 100.00%
# Extracted: SN a ey Po) s i $
# Ground Truth: for Breads_sq the Commis_ssary having no Orders to
#
# WER: 100.00%
# Extracted: <<  wy at  ys  eo  ayy as; ra
# Ground Truth: make provisions for yous_pt If any of your men
#
# WER: 150.00%
# Extracted: & <  = ce ras = S ee “4 ce Ce &
# Ground Truth: should desert or dies_cm you are immediately to
#
# WER: 137.50%
# Extracted: aS & og rN ee rc rh es Sc XN By
# Ground Truth: Recruit otherss_cm keeping your Company to the Estas_mi
#
# WER: 100.00%
# Extracted:
# Ground Truth: blishments_pt
#
# WER: 128.57%
# Extracted: PS Sy 4 nS ,* . S 4 a
# Ground Truth: s_2s_8ths_pt To Lieutenant Bacon of the Maryland
#
# WER: 450.00%
# Extracted: we’ rt ty ye c at , 2 Se
# Ground Truth: Independant Companys_pt
#
# WER: 800.00%
# Extracted: Xt  N& Ay an S Oo; YS <\
# Ground Truth: Sirs_cm
#
# WER: 100.00%
# Extracted:
# Ground Truth: As those Stockades on Pattersons Creeks_cm
#
# WER: 172.73%
# Extracted: a a> WA a. oe RN y < ee >- ns Se f sy Sy aN) SS ans ra
# Ground Truth: are only intended by way of cover to the Rangerss_cm and
#
# WER: 170.00%
# Extracted: os a a ~ as & a as ws .S = es ~~ NS sy — re . a
# Ground Truth: as a Receptacle now and then for Provisionss_sq you are
#
# WER: 122.22%
# Extracted: Ss ce < se é yr ss = ~~ Ss a
# Ground Truth: desired not to plan any works_cm which requires much
#
# WER: 100.00%
# Extracted: ey yo = i &. ae 4 wD Ce
# Ground Truth: time to executes_pt We have neither Men nor Toolss_cm
#
# WER: 100.00%
# Extracted: G ye ra y ae
# Ground Truth: to carry on the undertaking with vigours_pt
#
# WER: 150.00%
# Extracted: a x ©. UN YW a
# Ground Truth: I am s_etcs_pt s_GW
#
# WER: 250.00%
# Extracted: “oo oe eo < re oy oa SS Xx ge RK EO ~~ os, rs
# Ground Truth: s_2s_9ths_pt To Lieutenant Colonel Adam Stephens_cm
#
# WER: 225.00%
# Extracted: ok aS wy AP rt &. x eS -X
# Ground Truth: of the Virginia Regiments_pt
#
# WER: 100.00%
# Extracted: . , y 4
# Ground Truth: You are hereby Ordereds_cm so soon as
#
# WER: 228.57%
# Extracted: TS oe cs i ve ss or es KS S mS & or. * yO. =
# Ground Truth: the Waggons arrive from Alexandria and Fort
#
# WER: 171.43%
# Extracted: ra SN ny <4 i wg S Sy Fe €\ me s
# Ground Truth: Cumberlands_cm with Clothing and Armss_cm to see
#
# WER: 228.57%
# Extracted: a nos xe wy cor oh 9 re & AN S NN & a fe <
# Ground Truth: the men completely furnished with boths_sq and
#
# WER: 233.33%
# Extracted: > © Sx @ Ky = SS 9 > - sy iN  ee ~FR
# Ground Truth: march them immediately to Fort Cumberlands_sq
#
# WER: 200.00%
# Extracted: > Wo “as a o a vr Ray ~ * oy . > +» & rs a5 ay
# Ground Truth: observing to take up all the Salt which the
#
# WER: 314.29%
# Extracted: ~~ r CS ~ > ™ a nn ty . RS ~ ay ~ x ~~ Ae y * AY: e& SS
# Ground Truth: waggonss_cm provided by the commis_ssarys_cm will carrys_pt
#
# WER: 100.00%
# Extracted: S a Sy «= S wa = AN/ Ss
# Ground Truth: There will come down some of the country wags_mi
#
# WER: 222.22%
# Extracted: m tS at  ¥ es ans ~ ey a N & fs > se S RX 4 rg ” >
# Ground Truth: gonss_cm which must also be loaded up with Salts_pt
#
# WER: 162.50%
# Extracted: ~ ce < s Xe . 4s . + go > a ey
# Ground Truth: As there is some clothing wanting to complete
#
# WER: 157.14%
# Extracted: ay y x ri ‘ ~< & f a <= €,
# Ground Truth: the Companies at Fort Cumberlands_cm you are
#
# WER: 163.64%
# Extracted: aN aM a e yc a eo “y >> kh ~ <S ee Sy, NDS oe iy &
# Ground Truth: to take up for that purpose forty Coatss_cm thirty s_mi nine
#
# WER: 230.00%
# Extracted: AS & Ly Z a“ > ~ NT} a ey < a. a et \, 5 aes a" aa Qs SS SY, SS
# Ground Truth: waistcoatss_cm and fifty s_mi six pair of Breechess_sq thirty s_mi
#
# WER: 210.00%
# Extracted: x “ Xs oO a sy sas } sy o sehL ot € ». c ] oe " ae ey &
# Ground Truth: eight Hats and eighty Shirtss_sq which you are to have
#
# WER: 171.43%
# Extracted: AD mY Sy re cS < ASS Sg DS o ok e
# Ground Truth: s_2s_7s_4s_pt Letterss_cm Orders and Instructionss_pt October s_1s_7s_5s_5s_pt
#
# WER: 100.00%
# Extracted: og © ya ra
# Ground Truth: delivered out to the Companiess_cm according
#
# WER: 125.00%
# Extracted: eo PN rg SS > te ve oy Sy, ES
# Ground Truth: to the Return made me at Fort Cums_mi
#
# WER: 100.00%
# Extracted: <5 es yo + & SY
# Ground Truth: berlands_cm October s_2s_6ths_pt s_mi I have sent more
#
# WER: 137.50%
# Extracted: SS wy ce | as Ve ve. ee cS C n>
# Ground Truth: Suits than are neces_ssarys_cm in case of getting
#
# WER: 155.56%
# Extracted: e aS & & Xx. ee ; QQ) Ss Ww “A AS wey =
# Ground Truth: a Recruit s_etcs_pt You must do the best you
#
# WER: 137.50%
# Extracted: ee xs ” rey ks . og ge ay t> CN
# Ground Truth: can in Lodging the mens_cm as the Barracks
#
# WER: 112.50%
# Extracted: S ' og oe es ey GS me Oy
# Ground Truth: in the Fort are fulls_pt As Sergeant Wils_mi
#
# WER: 125.00%
# Extracted: & eo . : - 4 ae yg XY 5
# Ground Truth: per is waiting the return of the waggons
#
# WER: 128.57%
# Extracted: awe oi  oS Ns  \ ee  wey  ae. og
# Ground Truth: from the Forts_cm for neces_ssaries for Captain
#
# WER: 114.29%
# Extracted: & ve y ‘ v4 : és '
# Ground Truth: Hoggs Companys_sq so soon as they arrives_cm
#
# WER: 125.00%
# Extracted: & ay AN % se ye ra Ss | Re
# Ground Truth: you are to see that he receives such
#
# WER: 162.50%
# Extracted: es “ «f y & as ES S&S es ek £ S a .
# Ground Truth: things as he has orders fors_cm and dispatch
#
# WER: 128.57%
# Extracted: ya v4 C ; f . y, oy ;
# Ground Truth: him immediatelys_pt If no other Horsess_cm belongs_mi
#
# WER: 100.00%
# Extracted: a . et x rG Ny So ‘aN fs
# Ground Truth: ing to the Countrys_cm can be had heres_cm one
#
# WER: 200.00%
# Extracted: oS Dg / ES ey > SY Ng Es Ss ~~ x Sy &
# Ground Truth: of the Country Teams must be stoppeds_cm
#
# WER: 137.50%
# Extracted: x cy R Sg we ré a ca .& eS =
# Ground Truth: and the horses given to hims_pt You must
#
# WER: 150.00%
# Extracted: ys Ss ey es eS * & di Ky
# Ground Truth: engage the herdsmen to remain with
#
# WER: 100.00%
# Extracted: a ya Ca og NN =>
# Ground Truth: the Cattles_cm until they hear from the Coms_mi
#
# WER: 100.00%
# Extracted:
# Ground Truth: mis_ssary or from mes_pt You must engage
#
# WER: 187.50%
# Extracted: & ae wy SS & SQ oe | “, } wi RN ey 3 ‘SI
# Ground Truth: all the Coopers you can to make Barrels
#
# WER: 100.00%
# Extracted: gS al ws xe £ yo
# Ground Truth: for packing the Beefs_sq and if any of the
#
# WER: 212.50%
# Extracted: & > y os, <2, cS 2 tx &> & oh PANS g ~ ay Rr _-
# Ground Truth: Soldiers are Cooperss_cm they must be set ims_mi
#
# WER: 171.43%
# Extracted: sy e es A S&S a 4 © re oo mo &
# Ground Truth: mediately to works_pt You are to receive
#
# WER: 100.00%
# Extracted: ys fo Me Og 4
# Ground Truth: from the Stores here thirty pounds of
#
# WER: 114.29%
# Extracted: ~ Y Ro of y ya sf. D>
# Ground Truth: Goose s_mi which you will deliver to
#
# WER: 166.67%
# Extracted: ON & KS 4% a SS eS 2 x at
# Ground Truth: Captain Ashbys_qts Company as you pas_ss
#
# WER: 171.43%
# Extracted: MEQ ~ ES wy Gs AS oO aS we - rs roa
# Ground Truth: bys_cm directing him to be particularly cares_mi
#
# WER: 100.00%
# Extracted: yy x ay xy om 4 x
# Ground Truth: ful of its_pt s_mi If either of the Captains of
#
# WER: 112.50%
# Extracted: Ss rg of rx, ys Ng ce Pd ee
# Ground Truth: the Rangers should apply to you for Ammus_mi
#
# WER: 100.00%
# Extracted: o yi 4s Mg > G ay
# Ground Truth: nitions_cm you are to supply him from the
#
# WER: 114.29%
# Extracted: ’ Sg eo off ‘fy SS cv x.
# Ground Truth: Forts_pt A Drummers_cm with his Drums_cm is
#
# WER: 100.00%
# Extracted: aN oy yg ha rs ré A S
# Ground Truth: to be sent from this place with Sergeant
#
# WER: 157.14%
# Extracted: oS ®. ay 8 o &. ee oe e F eO\%
# Ground Truth: Wilpers_cm in the room of Duncan Fergusons_cm
#
# WER: 185.71%
# Extracted: ‘S) \ gS oN ay 3 R OS yoy S oy £3 a
# Ground Truth: Letterss_cm Orders and Instructionss_pt October s_1s_7s_5s_5s_pt s_2s_7s_5s_pt
#
# WER: 125.00%
# Extracted: ot SS 4% go < } gy ae ey , a t& ¢g s . Q
# Ground Truth: who is to go up to Fort Cumberlands_pt You are to see
#
# WER: 222.22%
# Extracted: : out a oe y ~*~ As ss 3 oS ey \ ey ee: wy XS & < —~ &
# Ground Truth: that the men of the Virginia Regiment are exers_mi
#
# WER: 150.00%
# Extracted: ry ey RNY oa & Xadt R ae Aa > eNO Ae £kS as A:
# Ground Truth: cised as often every day as the duty will admits_sq
#
# WER: 220.00%
# Extracted: se & eX & y Ww ds GS $ NS cS & SS y oo & s&s. x aN ss» Ye 2
# Ground Truth: and that they are practised also in shooting at Tars_mi
#
# WER: 144.44%
# Extracted: NS a S wy eg ae < ee & we  cS A ng
# Ground Truth: getss_sq and if there are any who are remarkably
#
# WER: 200.00%
# Extracted: Se . oa as ay ag ee act > < a Ly ay -
# Ground Truth: awkwards_cm particular pains must be taken with
#
# WER: 237.50%
# Extracted: N ES o- ey ‘~ a x y ™ tt se ce se S&S eo x ee & Ge
# Ground Truth: thems_pt You must observe on your march good
#
# WER: 100.00%
# Extracted: ‘ ra pf ra
# Ground Truth: order and disciplines_cm and see that no irregus_mi
#
# WER: 150.00%
# Extracted: fy e iY es q A \ a af ee 5 <
# Ground Truth: larities happens_sq and that the men are not
#
# WER: 300.00%
# Extracted: fo a aN & \ y So } a « RY ® aN \ es Ws an eS Ny: at 7 ae g ee
# Ground Truth: allowed to pillage the Countrys_cm which was very
#
# WER: 271.43%
# Extracted: N x SS wf = a ws xy RK RL ot ' aN en oN ~ ay EN ss
# Ground Truth: much complained of in the last Detachments_pt
#
# WER: 190.00%
# Extracted: a. ey & A xe SOY &\  C  SN ~~  ay ag & Cy  sf as S & PXy
# Ground Truth: You are to apply to Major Lewis for the Ins_mi
#
# WER: 275.00%
# Extracted: gs oO aS oS ot ov . © ‘Ss SA SS s, < x. XX » eS a ' oe "~ &
# Ground Truth: structions which I left with hims_cm and see
#
# WER: 225.00%
# Extracted: oy g ®Y Re a X mo. Sy XN
# Ground Truth: that they are observeds_pt
#
# WER: 220.00%
# Extracted: aw eS y gS o~ < a * ss yy’ ot
# Ground Truth: Given under my Hand s_etcs_pt
#
# WER: 533.33%
# Extracted: A tt EAN eh ft NY t EX NS © 0 aN as SANA, AN C3
# Ground Truth: Winchesters_cm October s_GW
#
# WER: 100.00%
# Extracted:
# Ground Truth: s_2s_9ths_pt s_1s_7s_5s_5s_pt
#
# WER: 100.00%
# Extracted: < Cc Oa wT &
# Ground Truth: s_2s_9ths_pt To Mrs_pt Commis_ssary Dick
#
# WER: 122.22%
# Extracted: & ~& N\ s . RS & < Cy ey Sy
# Ground Truth: You ares_cm so soon as you arrive heres_cm to
#
# WER: 144.44%
# Extracted: < & ya EAS | ’ ~ 7 re ANY a ae rg
# Ground Truth: give such directions as you shall see neces_ssary about
#
# WER: 100.00%
# Extracted: Shy gy 4
# Ground Truth: driving the Cattle to Fort Cumberlands_pt You are
#
# WER: 110.00%
# Extracted: og & e pe vs 7 a 4 cS  SS Ly
# Ground Truth: to send up Doctor Walkers_cm or go yourself theres_cm to
#
# WER: 237.50%
# Extracted: ‘ & ra . » cS \ . .* “ + a a ; & rg YY y >
# Ground Truth: see them killed and properly salteds_pt Whichever of
#
# WER: 187.50%
# Extracted: aS & RS “ Ve os s KS sy S ee 3 ta es eS
# Ground Truth: you remains heres_cm must purchase such a quantity
#
# WER: 160.00%
# Extracted: ~~ oy es Ny « at . XL ev a AS: 2 eo Qs .~ Y
# Ground Truth: of Pork as you imagine will be neces_ssary for the
#
# WER: 122.22%
# Extracted: MS  & OS “o ak 6 xe eg x se i
# Ground Truth: Troopss_cm upon the most reasonable terms you cans_sq and
#
# WER: 110.00%
# Extracted: © ' Ss ay S- ay ae  a  XD, &S ~~
# Ground Truth: oblige them to deliver it at whatever time you shall
#
# WER: 100.00%
# Extracted: ye s G fo Se hg |
# Ground Truth: judge most propers_pt You are to answers_cm out of the money
#
# WER: 271.43%
# Extracted: N p< S- eo oy e Ak * — 2 eo . eS es oy > Pw > Oks
# Ground Truth: in your handss_cm whatever Draughts Captain Hogg
#
# WER: 190.00%
# Extracted: Se a & os “oO ~ ay \ Ss 4 a <S\ ep os SS ; & % we
# Ground Truth: may draw on you for the subsistance of his Companys_cm
#
# WER: 190.91%
# Extracted: SX aN we S Se nN wy & r 8 ‘ os ae Sv 7 Yt QS Ex x AS ae
# Ground Truth: from time to times_pt You are to see that Coopers are
#
# WER: 233.33%
# Extracted: y Yes . G aN a . RB, ass ae” OX sy SS “4 £. ~~ & ~ ct R aS
# Ground Truth: engaged to make Berrels for the Provisionss_cm and to
#
# WER: 242.86%
# Extracted: ra Ly 4 <. a | Sy 4 AL y. g % AX Ca ( S a
# Ground Truth: s_2s_7s_6s_pt Letters Orders and Instructionss_pt October s_1s_7s_5s_5s_pt
#
# WER: 328.57%
# Extracted: Ss = Ny ON x < S ~ é Ss a Roe oa CS gS a NS Ss &sS * om 7 y
# Ground Truth: provide all other neces_ssaries for the Expeditions_cm
#
# WER: 250.00%
# Extracted: * x = To - sy ~ < > mo ot > ws AY R
# Ground Truth: which you know will be wanted
#
# WER: 211.11%
# Extracted: SS ry i at * “aN oe = ™~, Sy > ~*~ aS co ci rag yh ia ~<\
# Ground Truth: As there are several Contracts made by me to
#
# WER: 130.00%
# Extracted: © ay LF os a ay a se SS ay > ee &
# Ground Truth: have Cattle delivered here s_etcs_pt by the s_1sts_pt of next
#
# WER: 100.00%
# Extracted: iv S “ > gy ‘ a p 'S. | ts
# Ground Truth: months_cm s_mi I desire that for such as you receive ups_mi
#
# WER: 100.00%
# Extracted: Eq Y 4 y. ou nig my ys x
# Ground Truth: on that accounts_cm if you have money in your
#
# WER: 180.00%
# Extracted: Ak } ee x, a NU a  . ¥
# Ground Truth: handss_cm you make immediate payments_pt
#
# WER: 100.00%
# Extracted:
# Ground Truth: Given s_etcs_pt
#
# WER: 300.00%
# Extracted: \s ow eX Lv x ok « Ve wo
# Ground Truth: Winchester October s_GW
#
# WER: 450.00%
# Extracted: O27 Oy os a) & ? AS Wy ce
# Ground Truth: s_2s_9ths_pt s_1s_7s_5s_5
#
# WER: 100.00%
# Extracted:
# Ground Truth: s_2s_9ths_pt Winchester October s_2s_9ths_pt s_1s_7s_5s_5s_pt
#
# WER: 250.00%
# Extracted: oS » Os Sy aS
# Ground Truth: Parole Williamsburghs_pt
#
# WER: 100.00%
# Extracted: es yi e 8
# Ground Truth: One Subalterns_cm one Sergeants_cm one
#
# WER: 185.71%
# Extracted: SY s ok S ro ’ & a Q &, tS % eS
# Ground Truth: Corporals_cm one Drummer and twenty five private
#
# WER: 140.00%
# Extracted: tS  rs ‘> | c& eS, Ex - 4} &> Ss. ery Se .
# Ground Truth: mens_cm the Guard to s_mi day s_mi Captain Peachy is
#
# WER: 142.86%
# Extracted: = a & a ° ey < mW es =
# Ground Truth: ordered to take upon him the command
#
# WER: 142.86%
# Extracted: YY  “4 , YS “SS eo Sy wT cf ys
# Ground Truth: of the Recruits which arrived here under
#
# WER: 200.00%
# Extracted: yr me “NS “ SY we cs yg & Sg r & e oa
# Ground Truth: Lieutenant Hall and Ensign Prices_sq who are
#
# WER: 275.00%
# Extracted: x at. a & ~ 2 ~ \ ne ee EAN og < Ww . S&S ~ SS we SS t ‘*®
# Ground Truth: also ordered to act under hims_cm until further
#
# WER: 150.00%
# Extracted: ‘iS oe Ss rv gy & “a of -
# Ground Truth: orderss_mi Ensign Hedgemans_cm and the Recruits
#
# WER: 100.00%
# Extracted: ee ya ra
# Ground Truth: which arrived with hims_cm are ordered to join
#
# WER: 171.43%
# Extracted: AN = ~ <Q ee & Ds s es Wy & s
# Ground Truth: Lieutenant Kings_cm and be under his command
#
# WER: 200.00%
# Extracted: & ree > uf . ae ro LA r&) S ro &
# Ground Truth: until further orderss_mi Lieutenant Eustaces_cm and
#
# WER: 127.27%
# Extracted: Ss fg y CS ety 4 a CN rm Se y Tg & e
# Ground Truth: the eight men with hims_cm are to join s_blas soon as
#
# WER: 228.57%
# Extracted: WS AGES Te & SR ag oy - c> wey Ka ay oe S S s
# Ground Truth: they arrive at Fort Cumberlands_br the Company
#
# WER: 171.43%
# Extracted: ' ra Ct A Ce SS ee oe ES ey ue 2
# Ground Truth: which Captain Waggener commands at presents_sq s_mi
#
# WER: 150.00%
# Extracted: Qu Ng 4 Ra & af S Ry " oy _ *e & we “ee
# Ground Truth: and the Party left with Sergeant Shaws_cm is to res_mi
#
# WER: 150.00%
# Extracted: cy ra N . Ss a 2 7 C y g Sf
# Ground Truth: turn to their respective Companiess_cm so soon as
#
# WER: 190.00%
# Extracted: a BV ‘ & S ef SO x . 4 Oy ON Cg ie Ce ” Q, ott &
# Ground Truth: they reach the Fort s_mi The Commis_ssary is to see
#
# WER: 300.00%
# Extracted: ay ws &\ a 5 © Re a « | a . o> ce eS at S SS  q &® e.
# Ground Truth: that the Magazine is secureds_cm by fastening
#
# WER: 255.56%
# Extracted: nS oN of Se Ly > oa ov “ @e Z “ft we ‘ ey R. K Sy = LY & ey €
# Ground Truth: up the windows s_etcs_pt better than they now ares_pt
#
# WER: 160.00%
# Extracted: Se . 7 a x OY ce sy na ( ay 3 we e oy ey
# Ground Truth: The Officers are to see that the men are clos_mi
#
# WER: 262.50%
# Extracted: ~ <O” SX -~ «a é cA ee < co! es Fag eo Sy om ww < ates Ss. ab ~~
# Ground Truth: Letterss_cm Orders and Instructionss_pt October s_1s_7s_5s_5s_pt s_mi s_2s_7s_7s_pt
#
# WER: 208.33%
# Extracted: Ww ee Rg  > eS a“ 8 a ay Dy os Ve ao & oe XQ reo ° ae .- et & & = &
# Ground Truth: thed to s_mi morrows_cm and to be very particular in their Accounts
#
# WER: 220.00%
# Extracted: ~~} S st Q Sy it o> aot: ss -™ cs Ra &. AS ahs «> & & ; oa a SA
# Ground Truth: of what they receives_pt They will also receive Arms so
#
# WER: 240.00%
# Extracted: < 2S x a  a  = SS - >.  = y oe KR e Sy . ™, oy gs — aN & aS Os
# Ground Truth: soon as they arrive from Fort Cumberlands_cm to complete their
#
# WER: 100.00%
# Extracted: rg ra ye Ss ay y |
# Ground Truth: Recruitss_pt They are to see that each man distinguishes
#
# WER: 255.56%
# Extracted: ~ LYN xe XK - x tax S S a e wo as a ae - ce, $ SS a. ws ANS wy
# Ground Truth: his Firelock by some particular marks_cm which the Subs_mi
#
# WER: 141.67%
# Extracted: ay &\ &S AN S Ka \ a et a DS ae 2 = a, py t¢ cay
# Ground Truth: alterns of the Company are to enter in a Books_cm they are
#
# WER: 172.73%
# Extracted: ~ sy NX SN 4 . * < a3 eS S SSN wn Ne Q. a\ > a oa
# Ground Truth: to keep for that purposes_pt Every Officer is to provide an
#
# WER: 181.82%
# Extracted: cn y oS Se os » oS Sy Ss x SN sé ee =. = ANS ™~ ow a ee
# Ground Truth: Orderly Book to enter the Orders in as they is_ssue every
#
# WER: 225.00%
# Extracted: Vs Le a > Se aN Ss ~~ S S&S cs at a & wy ~ Ww rss
# Ground Truth: day regularlys_cm that they may examine them oftens_cm
#
# WER: 275.00%
# Extracted: wo e& A - SN ey ~ EN ~ > wk as “~ ee 3s oy — at ae we & .
# Ground Truth: and see they are duly complied withs_pt Captain
#
# WER: 300.00%
# Extracted: aw ) go rv KS 4 gS , rs ro | < 4 , ra \“* ’ ?
# Ground Truth: Bronaughs_cm Lieutenant Stewarts_cm Blegg and Williamss_cm
#
# WER: 357.14%
# Extracted: oe < ve Ss ~~ =~ ~ . m~ SS a > Ss . aed Ns = vas ew a ae 7 ~~ & es
# Ground Truth: sent Recruitings_cm and to Rendezvous at Alexandris_mi
#
# WER: 380.00%
# Extracted: NOS  “ N ~  ~ m~, “sy  \.  on “ x \ “ a wh Eres . oS ‘
# Ground Truth: as_cm the s_1st of Decembers_pt
#
# WER: 100.00%
# Extracted:
# Ground Truth: s_GW
#
# WER: 257.14%
# Extracted: L QQ wy cS ee co - oN ds oN a ‘es aS s No & S &>
# Ground Truth: s_3s_1sts_pt To Captain Robert Spotswoods_cm of the
#
# WER: 500.00%
# Extracted: a oy Ya 3s é <a mR Qs a? &
# Ground Truth: Virginia Regiments_pt
#
# WER: 128.57%
# Extracted: wy WY. on ~, ~ - e ye. g
# Ground Truth: You are hereby ordereds_cm as soon as
#
# WER: 233.33%
# Extracted: cN Xx Sy S coy rs ) =~ wt c. wv cr ~ ~AYy =S ~ ws - aN Cc ‘s
# Ground Truth: the Clothes and Arms arrives_cm to furnish all the
#
# WER: 450.00%
# Extracted: Ss SS oe ~* i Sh aS <>  <  “s .  ee  a4  Yy a ae Xt ~ NQ ay ere SS ey Sy ro * ~
# Ground Truth: men who now Rendezvous at Fredericksburghs_cm
#
# WER: 283.33%
# Extracted: & of we ¥ ’ gS 4  xY  og  Sy re ‘ s ae A Rs Ye
# Ground Truth: with boths_sq and march them immediately
#
# WER: 242.86%
# Extracted: ae x aS a we RS) [ ae < oy . oy 50 eu wey £N ey
# Ground Truth: with the utmost dispatch to Fort Cumberlands_cm
#
# WER: 255.56%
# Extracted: a ao. ~  ey  o ay + ~ > ay Ray XN ¥ . - SS ty SY & & a  - 3
# Ground Truth: to reinforce the Garrisons_pt s_mi When you arrive at
#
# WER: 312.50%
# Extracted: ~ NY Xe Sy Ss r Ss x. Ss > & * x ~< a, ws Ss os “a mS we < oe Sa Wry
# Ground Truth: Winchesters_cm you must provide your men with Cars_mi
#
# WER: 200.00%
# Extracted: aN an 7 SON, > a ey > BS & os r & es, aw S. & << s oc
# Ground Truth: tridgess_pt s_mi You are to be very careful and circums_mi
#
# WER: 233.33%
# Extracted: a SS! Ny a <> AS x? a ey x “Sy ee a ae > ar 0 wz ae & BY
# Ground Truth: spect in your marchs_sq and see that your men
#
# WER: 200.00%
# Extracted: aN ce > “s Oo aS oe & os 2g 3 re & é ey a
# Ground Truth: do not on any account whatsoevers_cm plunder or
#
# WER: 162.50%
# Extracted: RN &s X9 eo Y < EX PN w wh ty Sr CaS
# Ground Truth: pillage the Houses which the people have deserteds_cm
#
# WER: 111.11%
# Extracted: co ES S & ESS ay i Sa é hy
# Ground Truth: or any otherss_cm s_mi or Plantationss_pt s_mi Lieutenant Fras_mi
#
# WER: 200.00%
# Extracted: « cc . & Os, ONS a ey roy P e& we > Ke } a > rs
# Ground Truth: zier and Ensign Carters_cm are appointed to this Coms_mi
#
# WER: 100.00%
# Extracted:
# Ground Truth: mand
#
# WER: 100.00%
# Extracted: ¥ seo
# Ground Truth: Given s_etcs_pt
#
# WER: 1500.00%
# Extracted: ad <> Q fw KS Qy oe ry S sf NY yO ov st a
# Ground Truth: s_GW
#
# WER: 100.00%
# Extracted:
# Ground Truth: s_2s_7s_8s_pt Letterss_cm Orders and Instructionss_pt October s_1s_7s_5s_5s_pt
#
# WER: 128.57%
# Extracted: Sy . oy a : y. 4™ yy ot
# Ground Truth: s_1sts_pt To Captain John Mercer of the
#
# WER: 350.00%
# Extracted: weg yy a & x» os -7~
# Ground Truth: Virginia Regiments_pt
#
# WER: 100.00%
# Extracted: 3
# Ground Truth: You are hereby ordered to Rens_mi
#
# WER: 114.29%
# Extracted: a Ss ‘4 & 4 rai y 4
# Ground Truth: dezvous at Alexandria the first Day of
#
# WER: 142.86%
# Extracted: ES gS . ey ge A we ys ay ee
# Ground Truth: Decembers_cm with all the men you can
#
# WER: 100.00%
# Extracted: \ aw nS ra
# Ground Truth: raise by that times_pt
#
# WER: 100.00%
# Extracted:
# Ground Truth: Given s_etcs_pt at Fredericksburgs_cm
#
# WER: 200.00%
# Extracted: 9 4 Ss coy fs ra
# Ground Truth: November s_1sts_pt s_1s_7s_5s_5s_pt
#
# WER: 125.00%
# Extracted: SS > ae oon on
# Ground Truth: s_GW Aid de camps_pt
#
# WER: 142.86%
# Extracted: ASN a ag gS og 4g fs < 2 <>
# Ground Truth: Ns_ptBs_pt Captain Joshua Lewis is allowed to
#
# WER: 100.00%
# Extracted: we ra S Sy «ny & g
# Ground Truth: the s_1sts_pt of Decembers_cm to Rendezvous at Alexs_mi
#
# WER: 1000.00%
# Extracted: AN < f \ se “& € \9 e. eo
# Ground Truth: andrias_pt
#
# WER: 100.00%
# Extracted:
# Ground Truth: s_1sts_pt To Mrs_pt Boyds_cm Paymasters_pt
#
# WER: 120.00%
# Extracted: S ro rd eS ay es
# Ground Truth: As Colonel Stephen has brought
#
# WER: 110.00%
# Extracted: & “ey sy a rN x P a y sy? &
# Ground Truth: s_lbs_1s_0s_0s_0 which I wrote for to pay off the Troopss_cm
#
# WER: 162.50%
# Extracted: N f SS & eo * \ ee Sg ye Sa ~ <
# Ground Truth: it will save you a journey to Williamss_mi
#
# WER: 133.33%
# Extracted: y SN £ Sy ro a S ES Po oy - 49
# Ground Truth: burg at this times_qo but I think it absolutely
#
# WER: 100.00%
# Extracted: y, V4 vs . R ‘ "
# Ground Truth: neces_ssary that you shoulds_cm after paying the
#
# WER: 137.50%
# Extracted: aXs 3S at & Sy ce sy PAN < a es
# Ground Truth: Troops in Garrisons_cm go into Augustas_cm to pay
#
# WER: 142.86%
# Extracted: A Sy > wg Gg oe S & <. ae
# Ground Truth: off Captain Hoggs Companys_cm which is now
#
# WER: 100.00%
# Extracted: rs re 4 eG \ ig \
# Ground Truth: completes_sq unles_ss you can send the money
#
# WER: 137.50%
# Extracted: SN  &  Sg E> y o : ou eo << ag
# Ground Truth: by Mrs_pt Mcs_pt Clenachans_cm or some safe hand
#
# WER: 166.67%
# Extracted: OG a } | a re 4 Sy | 9
# Ground Truth: from hences_pt The Recruits at Fort
#
# WER: 110.00%
# Extracted: ww ye eS , ra wh, we 5 Ng ® Y
# Ground Truth: Cumberland are all paid off to the s_1sts_pt of Ocs_mi
#
# WER: 100.00%
# Extracted: ey  ©  és wy ys ys wb ra
# Ground Truth: tober as private mens_cm there being no distincs_mi
#
# WER: 166.67%
# Extracted: a a a ay “S gy . 5 = hy
# Ground Truth: tion made between them and Sergeantss_cm
#
# WER: 150.00%
# Extracted: Ss ay ye y as SS LS = t7
# Ground Truth: none having yet been regularly appointeds_pt
#
# WER: 114.29%
# Extracted: wm, vw | Ss & fy 7 ”
# Ground Truth: Colonel Stephen will give you an acs_mi
#
# WER: 100.00%
# Extracted: re ys: yg Oy Ss AS SG
# Ground Truth: count of those he has paids_cm and how s_mi
#
# WER: 157.14%
# Extracted: WW ra S a « rs gS : AO x .
# Ground Truth: If any have received Sergeants pays_cm it
#
# WER: 142.86%
# Extracted: RR | yw , Se. cs yy re ' wid
# Ground Truth: must be deducted next payments_qo as also
#
# WER: 166.67%
# Extracted: « S & a % oy oO kK a re
# Ground Truth: Letterss_cm Orders and Instructionss_pt November s_1s_7s_5s_5s_pts_2s_7s_9s_pt
#
# WER: 100.00%
# Extracted: rs : va >
# Ground Truth: two s_mi pence per months_cm from each non s_mi commis_ssioned
#
# WER: 200.00%
# Extracted: } Sg ‘ \ ‘ > rc ce y  a. Ww 4 ' |
# Ground Truth: Officer and Soldier for purchasing mediciness_sq s_mi
#
# WER: 109.09%
# Extracted: aN ~ , Sy Ny , cay ch Ss SO é “
# Ground Truth: this is to be paid to the Surgeon Quarterlys_pt There is
#
# WER: 108.33%
# Extracted: NY x oy ~ SS s Xh ~ aS SS > oo ag
# Ground Truth: also six s_mi pence per month to be stopped from the Drums_mi
#
# WER: 125.00%
# Extracted: s re wk « aS N = > aN S SS an Os se ag
# Ground Truth: merss_cm to be paid to the Drum s_mi Major for teaching thems_cm
#
# WER: 100.00%
# Extracted: wy a AS ce 4 re oe
# Ground Truth: and repairing the Drumss_pt s_mi These deductions you are
#
# WER: 140.00%
# Extracted: CS <= . a << oe < x ce “S A ot | x
# Ground Truth: hereby ordered to make each pay s_mi days_sq unles_ss couns_mi
#
# WER: 144.44%
# Extracted: aN gS fy Se rey sy aw c¢ ; x SS rey =
# Ground Truth: termanded by the Governor or myselfs_pt If any nons_mi
#
# WER: 214.29%
# Extracted: SS S . S gS 2 ay ce - ak 2 5 & ty wy
# Ground Truth: commis_ssioned Officer or Soldier should happen to
#
# WER: 100.00%
# Extracted: Sg S wh ss 4 og ms v »
# Ground Truth: dies_cm he is to be continued on the pay roll as an efs_mi
#
# WER: 140.00%
# Extracted: ee 6 & oh SN O& Sy rs ye wv ae ce at OY
# Ground Truth: fective man for twenty eight dayss_cm to pay for his
#
# WER: 180.00%
# Extracted: oft \ a Xs yes i ) al ay
# Ground Truth: Coffins_cm s_etcs_pt I am s_etcs_pt
#
# WER: 155.56%
# Extracted: AY ao &) i ie \ 7 es ky 3 \ is gy 4
# Ground Truth: s_1sts_pt To Commis_ssary Joness_cm s_mi Or to George Conways_pt
#
# WER: 133.33%
# Extracted: oy yO ts Ks & i> AN. a
# Ground Truth: You are hereby Ordered to deliver
#
# WER: 200.00%
# Extracted: ay Ss ~ < & aS er “y w ~ Os ee Sf S > € - ~
# Ground Truth: to Sergeant Wilper s_bltaking his receipt for the sames_br
#
# WER: 175.00%
# Extracted: oN  ~~ x a x A “ ~ WY SS yr 4 . '
# Ground Truth: for the use of Captain Hoggs Companys_cm eight
#
# WER: 200.00%
# Extracted: SS ve wo - x ss a3 wh ow f gy oa Sy tg
# Ground Truth: Regimental Coatss_cm ten Waistcoatss_cm ten pair of
#
# WER: 200.00%
# Extracted: SS wes x + & u rs LY o iy “AN & at G
# Ground Truth: Breechess_cm nine Hatss_cm eleven Shirtss_cm as many
#
# WER: 125.00%
# Extracted: & Oy ESN oe t » S&S s Wy Rn
# Ground Truth: pair of Stockingss_cm and the same quantity of
#
# WER: 100.00%
# Extracted: ' re ow & S ry Ly ec
# Ground Truth: Shoess_pt s_mi You are also to deliver to the said
#
# WER: 150.00%
# Extracted: ro & BY & aw X Oy & » > “ c SN wy ae
# Ground Truth: Wilpers_cm for the use of the said Companys_cm s_mi twelve
#
# WER: 200.00%
# Extracted: AW  &s  eo  . SA g RSS ~ _ wy en ow,
# Ground Truth: Musquetss_sq twenty Bayonetss_cm and ten Cartouchs_mi
#
# WER: 137.50%
# Extracted: X > & %: 4 nO ae a - eo Sy
# Ground Truth: Boxs_qtss_cm out of those Arms now in Stores_pt
#
# WER: 1100.00%
# Extracted: . Ss OY es > ye tS S ° ‘ ae
# Ground Truth: s_GW
#
# WER: 100.00%
# Extracted:
# Ground Truth: Ns_ptBs_pt The Bayonets must be delivered out of those
#
# WER: 100.00%
# Extracted: rg & — SQ as & € & x
# Ground Truth: loose ones in the Stores_qo You are also ordered to des_mi
#
# WER: 100.00%
# Extracted: y. Ss rd
# Ground Truth: liver twenty Blanketss_pt
#
# WER: 155.56%
# Extracted: o\9 ( \ SS A ee G wey 8 c eh eS se .
# Ground Truth: Octos_pt s_3s_0ths_pt To Sergeant David Wilpers_cm of the Virginia
#
# WER: 100.00%
# Extracted:
# Ground Truth: Regiments_pt
#
# WER: 228.57%
# Extracted: oe Ss t> oS SS) KY SX ye a AS > eS N ag ya eS
# Ground Truth: s_3s_0s_0s_pt Letterss_cm Orders and Instructionss_pt December s_1s_7s_5s_5s_pt
#
# WER: 150.00%
# Extracted: Sy Se  } f  ae > PS  eo S.
# Ground Truth: Hoggs_qts Companys_cm if any opportunity offerss_pt
#
# WER: 166.67%
# Extracted: 4 & a 3 cS e ae Re s ay
# Ground Truth: You are to be particularly exs_mi
#
# WER: 200.00%
# Extracted: & w ys A QL mS We & SS RN <y “a ‘ a
# Ground Truth: act and careful in these paymentss_qo sees_mi
#
# WER: 171.43%
# Extracted: yw  thy  a Ps & ~ 4 <r a& —<— yg a
# Ground Truth: ing that there is no disagreement between
#
# WER: 128.57%
# Extracted: ae rd 9 re e ESS Xo ob “
# Ground Truth: the Returnss_cm and your Pays_miRollss_sq as there
#
# WER: 100.00%
# Extracted: . ™ ; V4 |
# Ground Truth: will be strict examination into it hereafs_mi
#
# WER: 100.00%
# Extracted: XO eS
# Ground Truth: ters_pt I am s_etcs_pt
#
# WER: 100.00%
# Extracted:
# Ground Truth: s_GW
#
# WER: 225.00%
# Extracted: c  ry AS a KS a Y&s > G3
# Ground Truth: Alexandrias_qo December s_3s_cm s_1s_7s_5s_5s_pt
#
# WER: 250.00%
# Extracted: SN aw a . 2 ed CS Od Ww wy x ne SY. gN &S
# Ground Truth: s_5ths_pt To the Honourable Robert Dinwiddies_cm
#
# WER: 450.00%
# Extracted: SQ rc . oS  So AW  &  ws o
# Ground Truth: Esquires_sq Governors_pt
#
# WER: 233.33%
# Extracted: ft A as aN 4 x ‘ ) | e aS 7 . 5
# Ground Truth: I have sent the Bearers_cm Caps_mi
#
# WER: 228.57%
# Extracted: a7 a co =<} Ni wy og ay my Ww > < oa AQ ~ >
# Ground Truth: tain John Mercer s_blwho has accompts to
#
# WER: 285.71%
# Extracted: <n & ae <. wy ay ; ey s ot “~ - oO “Ne aX ~ a ty ra Pe
# Ground Truth: settle with the Committee to the Treasus_mi
#
# WER: 150.00%
# Extracted: pS «iS eo, > aA. y x wy os & y Ss
# Ground Truth: rer for the balance of that ten thousand
#
# WER: 250.00%
# Extracted: So > re oo < a a Ss Ss = SS ee wg 3 Cc
# Ground Truth: poundss_sq and to aquaint your Honours_cm
#
# WER: 150.00%
# Extracted: ay  x re eo rs ee sy a ae
# Ground Truth: that meeting with Letters at Frederickss_mi
#
# WER: 200.00%
# Extracted: N : g rs sy < Cs y ee r ey SN
# Ground Truth: burghs_cm as I returned from Williamsburghs_cm
#
# WER: 116.67%
# Extracted: SS = Oe re 4S ye gS
# Ground Truth: informing me that all was peaceable
#
# WER: 142.86%
# Extracted: 4S oO ¢ Sh ev ey oS ES “ i
# Ground Truth: aboves_cm and that nothing was so immes_mi
#
# WER: 150.00%
# Extracted: ey Cet S re qm & SS  xq va we ®  S
# Ground Truth: diately wanting as Salts_pt I got what I
#
# WER: 171.43%
# Extracted: o “Ss on y 4 “¢ ee ae, a) A oa @
# Ground Truth: could at that places_cm and hastened on
#
# WER: 200.00%
# Extracted: og aX & a a CC ry 7 oN oY cS Vy Ee A ra aA & 4
# Ground Truth: here to engage mores_sq s_mi to receive the Recruits
#
# WER: 211.11%
# Extracted: ss rs x ® A> ‘Sy N™ r ss . a eo QQ DY =, ~ - ay =
# Ground Truth: that were expected ins_sq and to wait the ars_mi
#
# WER: 188.89%
# Extracted: Sy | \ A am Sy fg oe abd - cS ie 0 yy Ny oy KAN
# Ground Truth: rival of the Ves_ssel with armss_cm s_etcs_pt from James
#
# WER: 100.00%
# Extracted: yo L yd
# Ground Truth: Rivers_cm in order to forward them up with
#
# WER: 137.50%
# Extracted: co ‘4 oS 4 SN yi rg 4 wy x |
# Ground Truth: the greater dispatchs_pt The Ves_ssel is not yet
#
# WER: 100.00%
# Extracted:
# Ground Truth: arriveds_pt s_mi
#
# WER: 175.00%
# Extracted: ry se c Mg a fg &yY
# Ground Truth: I have impatiently expected
#
# WER: 125.00%
# Extracted: a aN, ris AS gS ‘ JN x rg a
# Ground Truth: to hear the result of you Honours Letter
#
# WER: 100.00%
# Extracted: *. x” rg ro ri rs VR
# Ground Truth: to General Shirleys_sq and with that the des_mi
#
# WER: 150.00%
# Extracted: rey & 4 a S § yy oy AS
# Ground Truth: Letters Orders and Instructionss_pt December s_1s_7s_5s_5s_pt
#
# WER: 133.33%
# Extracted: oy gS ia v vg 4 eg rs a rem ‘Aa \
# Ground Truth: lays may not prove ominouss_pt In that cases_cm I
#
# WER: 170.00%
# Extracted: men sy NS Sh, & 4 sx *” KX thy wh. rap XG 4 f w et
# Ground Truth: shall not know how to acts_sq for I can never
#
# WER: 157.14%
# Extracted: os & = S es, a ro VQ x So Co
# Ground Truth: submit to the command of Captain Dags_mi
#
# WER: 185.71%
# Extracted: F ng Ss Ya “ e & a ys a Yy & <,
# Ground Truth: morthys_cm since you have honoured me with
#
# WER: 116.67%
# Extracted: SN *. o se eS iy og
# Ground Truth: the Command of the Virginia Regiments_cm
#
# WER: 183.33%
# Extracted: og  <<  ASS, e aN =. = ' - = at:
# Ground Truth: s_etcs_pt The Country has sustained inconceivable
#
# WER: 257.14%
# Extracted: fog we WEN €5 yw SS a . = oN a < &y & ' xy \* s
# Ground Truth: los_sses by delaying the Commis_ssaries at Williamsburghs_qo
#
# WER: 200.00%
# Extracted: aS a & a ‘ wh : sy ss SS aS 4 oo , ‘S re S &
# Ground Truth: many of the Carolina Beeves are deads_cm through abs_mi
#
# WER: 120.00%
# Extracted: aN 4 = way. ef XD S of ey ) Og ES ty
# Ground Truth: solute povertys_sq and the chief part of them too poor
#
# WER: 150.00%
# Extracted: w a Hy aN ~ &) : dy A Y a ‘ a A Ly . / wh =
# Ground Truth: to slaughters_pt We are at a los_ss how to acts_cm for want
#
# WER: 100.00%
# Extracted: a & SH < a eh & wt KR
# Ground Truth: of the mutiny Bills_sq and should be obliged to
#
# WER: 100.00%
# Extracted: Ss ®y & > a we s rN
# Ground Truth: your Honour to have fifty or an hundred printeds_cm
#
# WER: 130.00%
# Extracted: RS X AS < ON s&s SS rf aA ; a & & eS
# Ground Truth: and sent by the Bearers_pt There is a clause in
#
# WER: 222.22%
# Extracted: on ON SS ES NS ~ ~ as a & eS “ na 2 % es vn, oe ae ~*~
# Ground Truth: that Bills_cm which if you are not kind enough
#
# WER: 200.00%
# Extracted: aN NX wy A . oN SS Q. > S me? Ss — Na\ x y
# Ground Truth: to obviates_cm will prevent entirely the good intens_mi
#
# WER: 166.67%
# Extracted: > ~~ ao : “ y oe Se = Sg ae ye “ ey ~S
# Ground Truth: tion of its_qo is_ptes_pt delaying the execution of Sens_mi
#
# WER: 175.00%
# Extracted: Ss Oa ., nh SS m™ > Py a wey ahs 7 AR a
# Ground Truth: tencess_cm until your Honour shall be made acs_mi
#
# WER: 171.43%
# Extracted: S. y 4 yy >. y y yO 4 f  sy f
# Ground Truth: quainted with the proceedings of the Courts_pt
#
# WER: 187.50%
# Extracted: “sk XS - OY SS NS a y “* ed es S ae S ~~
# Ground Truth: Thiss_cm at times when there is the greats_mi
#
# WER: 187.50%
# Extracted: s ey \ * RS A S ‘SS aN | | “> é ~ y
# Ground Truth: est occasion for Expampless_cm will be morally ims_mi
#
# WER: 155.56%
# Extracted: Se SS © a PS PS ‘ os ‘ eS. > nN “ SS
# Ground Truth: pos_ssible s_blI mean while we are on our marchs_sq
#
# WER: 166.67%
# Extracted: a  xs Sy  A  a  oa ey . vy vy & ae rs NS =
# Ground Truth: perhaps near the Ohios_br when none but strong pars_mi
#
# WER: 109.09%
# Extracted: we “4 es Py &, i) a A cS y. oo ey
# Ground Truth: ties can pas_ss with safetys_qo at all times it must be
#
# WER: 114.29%
# Extracted: a re rg re ra cS =. =
# Ground Truth: attended with great expences_cm trouble and inconves_mi
#
# WER: 187.50%
# Extracted: gS oe 7  Q  Ky | oe a os ee y SS : > >
# Ground Truth: niencys_pt this I represented to Colonel Corbin and
#
# WER: 125.00%
# Extracted: ‘> ) ‘cs y. a ro ‘ | w Xs
# Ground Truth: some other Gentlemen of the Councils_cm when I
#
# WER: 162.50%
# Extracted: a > — t os Ne ' S> ot row et rf sx
# Ground Truth: was downs_sq who said that that objection to
#
# WER: 100.00%
# Extracted: ro reg Oy yd y fy
# Ground Truth: the Bill would be removeds_cm by your Hons_mi
#
# WER: 137.50%
# Extracted: a y NY oo { Ss x ro : > a
# Ground Truth: ours giving Blank Warrantss_cm to be filled up
#
# WER: 157.14%
# Extracted: > eS ey Sy & . e& - GY ie a
# Ground Truth: as occasion should requires_pt This would effecs_mi
#
# WER: 125.00%
# Extracted: ye J 4 S  rk >  p eS  s Sa
# Ground Truth: tually remedy all those Evilss_cm and put things
#
# WER: 100.00%
# Extracted: a ya es
# Ground Truth: in their proper channels_pt
#
# WER: 100.00%
# Extracted: ah PS ~ ry a, ‘2 Ss
# Ground Truth: We suffer greatly for want of Kets_mi
#
# WER: 100.00%
# Extracted: Kd ra a y: oO VN ye
# Ground Truth: s_3s_0s_2s_pt Letters Orders and Instructionss_pt December s_1s_7s_5s_5s_pt
#
# WER: 100.00%
# Extracted: re a ‘Ss gS yl ye
# Ground Truth: Kettless_qo those sent from below being Tins_cm are of
#
# WER: 100.00%
# Extracted: og of’ we SS yg
# Ground Truth: small durations_pt We shall also in a little times_cm
#
# WER: 125.00%
# Extracted: n XN a me | &S hy ro , ras
# Ground Truth: suffer as much for want of Clothings_sq none
#
# WER: 188.89%
# Extracted: ‘Ss >) s & a “ BY eg x wy 3 we ’ SS < er x
# Ground Truth: can be got in these partss_qo those which Major
#
# WER: 100.00%
# Extracted: ON SS , &, WS ré,
# Ground Truth: Carlyle and Dalton contracted to furnishs_cm
#
# WER: 200.00%
# Extracted: r & o rk 2 ‘: ee x ay \& x » yA Ss"
# Ground Truth: we are disappointed offs_pt Shoes and Stockings
#
# WER: 100.00%
# Extracted: y A & < yy
# Ground Truth: we haves_cm and can get more if wanteds_cm but
#
# WER: 100.00%
# Extracted: x a cog ey ee oy ral
# Ground Truth: nothing elses_pt I should be glad your Honor
#
# WER: 120.00%
# Extracted: V4 a RN f a oS » ey ae y, Ss -
# Ground Truth: would direct what is to be done in these cas_mi
#
# WER: 122.22%
# Extracted: es <a x Px @ > < fey ey og cs
# Ground Truth: sess_sq and that you would be kind enough to
#
# WER: 100.00%
# Extracted: oe y 4 ya ra ys aA Sg
# Ground Truth: desire the Treasurer to send some part of the
#
# WER: 100.00%
# Extracted: - ) 4 ~ | | 4
# Ground Truth: money in gold and silvers_qo were this dones_cm we
#
# WER: 185.71%
# Extracted: = 4 Q cy os CA ye Sg Y agony e . x
# Ground Truth: might often get neces_ssaries for the Regiment
#
# WER: 100.00%
# Extracted: * yd ia S g
# Ground Truth: in Maryland or Pennsylvanias_cm when they
#
# WER: 100.00%
# Extracted: we ro ey g rg
# Ground Truth: can not be had heres_pt but with our money
#
# WER: 100.00%
# Extracted: es . ro gS ~ as ~ eS
# Ground Truth: it is is impos_ssibles_sq our paper not pas_ssing theres_pt
#
# WER: 100.00%
# Extracted: po y. ee :
# Ground Truth: The recruiting Service goes on exs_mi
#
# WER: 100.00%
# Extracted: er ys “4 gy ~ 7%
# Ground Truth: tremely slows_pt Yesterday being a day appointed
#
# WER: 100.00%
# Extracted: y ya e y 4 >
# Ground Truth: for Rendezvousing at this places_cm there came in
#
# WER: 100.00%
# Extracted: oo S KS yS nS e gS sh &
# Ground Truth: ten Officers with twenty men onlys_pt If I had
#
# WER: 137.50%
# Extracted: ~ oe  a  , Co ce we < Ly Ss oo
# Ground Truth: any other than paper moneys_cm and you appros_mi
#
# WER: 100.00%
# Extracted: <  rt .  rg  fe * ee re
# Ground Truth: ved of its_sq I would send to Pennsylvania
#
# WER: 137.50%
# Extracted: ws ™ es) ON) 4 oY ry rat eg Py =
# Ground Truth: and the Borders of Carolinas_qo I am confidents_cm
#
# WER: 142.86%
# Extracted: as ~ w Lt St 4 ea aha Cog C
# Ground Truth: men might be had theres_pt Your Honor
#
# WER: 266.67%
# Extracted: << os ig ago ~ wef o @ ee 2 <> co & a 4 &s
# Ground Truth: never having given any particular Directis_mi
#
# WER: 100.00%
# Extracted: v aN vA iy 4 |
# Ground Truth: ons about the Provisionss_sq I should be glad to
#
# WER: 112.50%
# Extracted: WN SA a y XY ye Sy Sb wg
# Ground Truth: knows_cm whether you would have more laid in
#
# WER: 112.50%
# Extracted: ye ot ‘ re . 4 re < rae
# Ground Truth: than what will serve for twelve hundred mens_sq
#
# WER: 100.00%
# Extracted: y 4 a ‘4 EG ys
# Ground Truth: that I may give orders accordinglys_pt
#
# WER: 114.29%
# Extracted: <" NA v owe gy : yy vf
# Ground Truth: As I can not now conceives_cm that
#
# WER: 157.14%
# Extracted: ff Kw ‘ wet rs ae i ow rw Y )
# Ground Truth: any great danger can be apprehended at
#
# WER: 114.29%
# Extracted: y hg S a | g | Cap
# Ground Truth: Fort Cumberland this Winters_sq I am sensibles_cm
#
# WER: 142.86%
# Extracted: , &  ve rv  ye  y c rey Cs *
# Ground Truth: that my constant attendance theres_cm can not
#
# WER: 266.67%
# Extracted: SN 5 > ae \) X *% < e oy oe S SSN ey iS iS
# Ground Truth: Letters Orders and Instructions Decembers_pt s_1s_7s_5s_5s_pt
#
# WER: 133.33%
# Extracted: os & ee ae eS Cg ay oe a © x 2S.
# Ground Truth: be so serviceable as riding from place making the
#
# WER: 200.00%
# Extracted: aN x KS =~ ~ ee XR, ey Ra wn & eS & & < oe
# Ground Truth: proper Dispositionss_cm and seeing that all our neces_ss_mi
#
# WER: 175.00%
# Extracted: = a. Pan oe >> = & se = Z <i> oy SY &
# Ground Truth: saries are forwarded up with dispatchs_pt I theres_mi
#
# WER: 150.00%
# Extracted: Ss s Ly < ™~ vs ~ re >) & =~ y
# Ground Truth: fore think it advisable to inform your Honour
#
# WER: 118.18%
# Extracted: Sy eo N\ Sy a ay re Rye ok SN; = og 4
# Ground Truth: of its_cm hoping that it will correspond with your own opinions_pt
#
# WER: 127.27%
# Extracted: ES = SS ro ch 4 a €; = s < > at ro
# Ground Truth: I forgot to mention when I was downs_cm that Mrs_pt Livings_mi
#
# WER: 130.00%
# Extracted: s we we gS a ~ re o> a& x o4 ~ eo
# Ground Truth: stons_cm the Fort s_mi Majors_cm was appointed adjutant to our
#
# WER: 120.00%
# Extracted: NS os 4 og g & v SS es & AN é
# Ground Truth: Regiments_qo s_mi I knew of none else whose long servitude
#
# WER: 100.00%
# Extracted: ya ya | SS rs ‘ a
# Ground Truth: in a military ways_cm had qualified better for the offices_cm
#
# WER: 171.43%
# Extracted: ay eS R a we eS SS x Rx, Xs > ey
# Ground Truth: he was appointed the s_1s_7ths_pt of Septembers_pt
#
# WER: 157.14%
# Extracted: wy ax  “!* w. \  a  & Ou nae 2 ne
# Ground Truth: Captain Mercers_qts pays_cm as aid de camps_cm
#
# WER: 150.00%
# Extracted: = . ~ x Oe  nt  5  Q  eS ‘ ae eg yo a ’
# Ground Truth: seems yet doubtfuls_sq I should be glad if your Honour
#
# WER: 100.00%
# Extracted: S Sa | NG ses ye ey @y 2 os
# Ground Truth: would fix its_qo so is Captain Stewartss_qo If Captain Stews_mi
#
# WER: 155.56%
# Extracted: oo ~~ nD oa Sy ay we co aE, oN wy ey Qa? Yor,
# Ground Truth: arts is encreaseds_cm I suppose all the Officers belonging
#
# WER: 170.00%
# Extracted: oe nN RON aS ay '  =  ~ ' a as  ~ XS ce Sy ex a
# Ground Truth: to the Light Horse will expect to have theirs augmens_mi
#
# WER: 155.56%
# Extracted: as rz ag => sy > “ ES eS ad S SS S ey
# Ground Truth: ted alsos_pt Colonel Stephenss_cm in a late letters_cm diss_mi
#
# WER: 220.00%
# Extracted: ow = S&S a oa as - “oO Ss & _ y SS a mS aS ay oA oy x “a &
# Ground Truth: covered an inclination to go to the Creek and Ches_mi
#
# WER: 150.00%
# Extracted: x os x S at * ~ ~ = oe sy oS ~ = >
# Ground Truth: rokee Indians this Winters_pt I told him where to aps_mi
#
# WER: 150.00%
# Extracted: “a ~—™ a sy Re ~ Se "> ~ gS Ss SS ES < =
# Ground Truth: plys_cm if he had any such thoughtss_pt I believes_cm on
#
# WER: 155.56%
# Extracted: a << SS Ss ~ as €S y SS ny = cs ro ea
# Ground Truth: so useful a Busines_sss_cm he might be spared until
#
# WER: 177.78%
# Extracted: is  <. & < S eS @ = aS = = a & a ~~ €
# Ground Truth: the Springs_pt If your Honor think proper to ors_mi
#
# WER: 100.00%
# Extracted: os SX SS SQ ws “oe MS
# Ground Truth: der the Act of As_ssembly for apprehending Desers_mi
#
# WER: 225.00%
# Extracted: X cs > yo GS S &\ Xs a. ie ~ ret a “~ S PN sy ez
# Ground Truth: terss_cm and against harbouring thems_cm to be published
#
# WER: 162.50%
# Extracted: SS eF Sy ee & & a, eo ee. ow oy oO ra
# Ground Truth: every Sunday in each parish Churchs_cm until the
#
# WER: 100.00%
# Extracted: <o ne Sg a re } gy ye
# Ground Truth: people were made acquainted with the Laws_cm it would
#
# WER: 111.11%
# Extracted: re AQ SS wt “A xX ay Sy < a
# Ground Truth: have a very good effects_pt The Commonalty in genes_mi
#
# WER: 150.00%
# Extracted: CS s x & MS aN Sw es am & < ee
# Ground Truth: rals_cm or more through ignorance than designs_qo few
#
# WER: 110.00%
# Extracted: S ya ew  eS & & a 9 ey a oo <
# Ground Truth: of them are acquainted that such a Law existss_qo and
#
# WER: 127.27%
# Extracted: eS ra ~ aN °- Ly & S & oy Og Rr. = &
# Ground Truth: there is no other certain way of bringing it to their
#
# WER: 133.33%
# Extracted: < m ~* ot &  gy “ nt  &  at Cx a
# Ground Truth: knowledges_pt There are a great many of the men
#
# WER: 100.00%
# Extracted: re a ES ¢ a ae KS
# Ground Truth: that did once belong to our Companiess_cm deserted
#
# WER: 137.50%
# Extracted: ot ‘ NS eo. we x Od * & wey gy
# Ground Truth: from the Regiments into which they were draughs_mi
#
# WER: 100.00%
# Extracted: wy Co a ‘
# Ground Truth: teds_cm that would now gladly return if they could
#
# WER: 142.86%
# Extracted: Wg cy a 4S & oh rl yee EN &
# Ground Truth: s_3s_0s_4s_pt Letters Orders and Instructionss_pt December s_1s_7s_5s_5s_pt
#
# WER: 150.00%
# Extracted: cen RS & ye { ON % mh . » aa rR»
# Ground Truth: be sure of idemnitys_pt If your Honor would
#
# WER: 175.00%
# Extracted: eS ‘Sg Ky ty cA ou af: x an RSS wv roe  oo Cd
# Ground Truth: be kind enough to intimate this to General
#
# WER: 133.33%
# Extracted: ry r> ay > g ee & oY < ay x -
# Ground Truth: Shirleys_cm or the Colonels of those Regimentss_cm s_mi it
#
# WER: 166.67%
# Extracted: SS < eS SS > re me 3 LK ae 2 (> ‘ ty» s
# Ground Truth: would be of service to uss_qo without leave we
#
# WER: 100.00%
# Extracted:
# Ground Truth: dare not receive thems_pt s_etcs_pt
#
# WER: 100.00%
# Extracted:
# Ground Truth: s_GW
#
# WER: 100.00%
# Extracted:
# Ground Truth: Alexandrias_qo December
#
# WER: 550.00%
# Extracted: rag rg | %* : N : | i \ 4
# Ground Truth: s_5ths_pt s_1s_7s_5s_5s_pt
#
# WER: 233.33%
# Extracted: Sn SG g > 58 gs f. o cc x. ce SS Xe “ee
# Ground Truth: s_5ths_pt To John Robinson Esquires_cm Speakers_pt
#
# WER: 260.00%
# Extracted: ay &S oe aN ie soy -  ~  es hae Y ay  Ay
# Ground Truth: The Bearers_cm captain John Mercers_cm
#
# WER: 155.56%
# Extracted: SSS a SEP oS e rN Q sk — af oe ry es “a
# Ground Truth: having leave to go down and Settle his acs_mi
#
# WER: 214.29%
# Extracted: xq  a & x ew Ss rg R & ‘ ih . > ot >.
# ...
# Ground Truth: you may enter intos_pt What I have engaged here
#
# WER: 385.71%
# Extracted: Cal > Poa eS a Pm a Enel ae ~ Ry aS < ox &/  oO,  aN  we oS 7 —~ AD  & > ~ oe es
# Ground Truth: s_3s_0s_6s_pt Letters Orders and Instructionss_pt Decems_pt s_1s_7s_5s_5
#
# WER: 233.33%
# Extracted: ¥ Zh f, Y ay A eeo>, “ly tty ty SP, oe gy %, tL > 32 a 3, *, eon
# Ground Truth: has been at s_2s_ss_sls_pt per bushels_pt You may procure
#
# WER: 237.50%
# Extracted: “ o- > Oe F OA So. at a J in wf NLD — ON, & ~~ ot can ~~
# Ground Truth: six or eight hundred bushel at that rates_cm
#
# WER: 175.00%
# Extracted: “My Lf: “Ay ea) ay ZS ee ” vA, FL, JP Ke, Lip, Lb
# Ground Truth: and see that they are forwarded to Winchess_mi
#
# WER: 222.22%
# Extracted: My } ay oL,.  Sogo  fn Ge .  - hep ?  we) “yD A, “Lr, . ky gen fen, fr
# Ground Truth: ter as expeditiously as pos_ssibles_qo in order to do
#
# WER: 371.43%
# Extracted: yp oS. 8 a c* ~ a ~ « » So SS ~ nw & ~, wa; Ss A 9 o~ & 2 > aos ~~
# Ground Truth: thiss_cm you must hire and impres_ss waggonss_qo
#
# WER: 285.71%
# Extracted: { ti ‘ hey ; Ay Y 1. - ih lox a Fr, Cry x ‘n “by Fifa AL, 7
# Ground Truth: those Horses which were sent round from
#
# WER: 200.00%
# Extracted: 2: € SN i ay s & & S LoS Sy * AR Lf ~* x < :
# Ground Truth: Williamsburghs_cm are also to go ups_sq and a milis_mi
#
# WER: 133.33%
# Extracted: iW ys we \ ‘ Ty xis Q ™™ ch) ah! AN
# Ground Truth: tary Chest which Mrs_pt Allen made for mes_cm is
#
# WER: 175.00%
# Extracted: A he, HK tf “Ly, ryt “4 Tay “Dy { 4 Y7 a “
# Ground Truth: to receive the first conveyance You are to
#
# WER: 480.00%
# Extracted: xs gS aS” - ~~ LS - oy “te Xe aS —_™ . oo So Se. a ao oe, ay x we ~ Ore
# Ground Truth: remain in Fredericksburgh and Falmouths_cm
#
# WER: 300.00%
# Extracted: oS RE ON. sa ye <> oh p ie 33 St yak ~ & eh on Pa Ss oo ae a=
# Ground Truth: seeing these things dones_cm until further Orderss_pt
#
# WER: 287.50%
# Extracted: ANS of ‘ S ~“ So ws < t SA. a ty seo oN. a 2 < & ~ ty 8 ss We
# Ground Truth: All the Recruits which now ares_cm and shall
#
# WER: 383.33%
# Extracted: . 2 5 an “ ‘> et 2 2, y Hy, Pe a, oA > 2 SH XN Ox, *7), en oy 2
# Ground Truth: arrive at Fredericksburghs_cm between this and
#
# WER: 466.67%
# Extracted: oe a cy _— a <= a x &  ™ ~~  ae  =  ge  SS 7? 2 Tyee ~~ ~ os eR & cf, a van ar =
# Ground Truth: the s_2s_5ths_pt Instants_cm must immediately proceed
#
# WER: 160.00%
# Extracted: Y yy < SS & os & ?
# Ground Truth: to the Rendezvous at Winchesters_pt
#
# WER: 262.50%
# Extracted: KS a . 4S « «& ~ Gas ay % Ny 8 ; Ain Ce, | ~ Nn oy ~* ~
# Ground Truth: Ns_qoBs_pt Enquire of Mrs_pt Dick and other Mers_mi
#
# WER: 383.33%
# Extracted: a ¥ bs ty AS, a“, & hey | ys: Ted, : oa, YB "4 SE; a “Y- > : a> Bi oa
# Ground Truth: chantss_cm whether Commis_ssary Walker has ens_mi
#
# WER: 166.67%
# Extracted: ¥° if ey = i oy ) “ft yf i ) ue “, y P04
# Ground Truth: gaged Salt of thems_qo if he hass_cm you have
#
# WER: 266.67%
# Extracted: » “ 49 ; a4, Ty » ir fy a VA ry ~ fy tn D.
# Ground Truth: then only to forward it ups_pt
#
# WER: 350.00%
# Extracted: e Ty, hn, Dp CoP Why yy fo, p- aN LY; < 7 :
# Ground Truth: Alexandrias_qo December s_5ths_pt s_1s_7s_5s_5s_pt
#
# WER: 240.00%
# Extracted: ae, Crp a“ tp. wan Le ny o L2 ae} “9, ee
# Ground Truth: s_8ths_pt To Captain Robert Stewarts_cm
#
# WER: 750.00%
# Extracted: i, a oy rs re, os y ae aS re Ss: a a a as
# Ground Truth: at Winchesters_pt
#
# WER: 100.00%
# Extracted: a \ dé * O
# Ground Truth: You are hereby required to take
#
# WER: 300.00%
# Extracted: “, ) b Mip v . Pry, | } i f ts, EM, ge ye ; fhe t ie ry 4 EDS, ; f
# Ground Truth: charge of the Recruits sent to Winchester by
#
# WER: 271.43%
# Extracted: T ‘t5 ' a oa nd 4s ¢€ xm Sy 2, 4 i ' Ae. by 4 Bn 7
# Ground Truth: Captain Gists_cm whose Son you must Order
#
# WER: 471.43%
# Extracted: QS of ga ms Say ae ed ~ > ta res ~ ] gu aS rant n ad £ Mh f a Sy 4 . & on SS wy & & & xe
# Ground Truth: to proceed immediately and join his Fathers_pt
#
# WER: 180.00%
# Extracted: = aS wh ae oe ae x - RX
# Ground Truth: Captain Gist this day received
#
# WER: 342.86%
# Extracted: x & lat, OY = Ss ES cs = a = Pos a — OX —*~. or cx cs ~ co et ~e, =
# Ground Truth: one hundred pounds to recruit withs_sq and
#
# WER: 266.67%
# Extracted: en wa “ 23 , ty > cP, >, “> “Le A te < “kx Ay ? a a “yy ~ ry, ? <*>
# Ground Truth: the same Orders that were given to the os_mi
#
# WER: 257.14%
# Extracted: we ww a : re wy » t AY v yeh ; “A as yn PN as ss
# Ground Truth: ther officers on the s_3rds_pt instant s_etcs_pt
#
# WER: 1100.00%
# Extracted: {* f 4, i J om Xe  (n, Pe va  “Ys
# Ground Truth: s_GW
#
# WER: 100.00%
# Extracted: oe
# Ground Truth: Alexandrias_qo December s_8ths_pt s_1s_7s_5s_5s_pt
#
# WER: 250.00%
# Extracted: f ay > TPY 7p, . “4 ) Ay g ‘ Li ~\ ‘as 4;
# Ground Truth: Letters Orders and Instructionss_pt December s_1s_7s_5s_5s_pt
#
# WER: 200.00%
# Extracted: Ve raps ‘ Pr, . s, - *, @ WZ)
# Ground Truth: s_1s_0ths_pt Alexandria December s_1s_0ths_pt s_1s_7s_5s_5s_pt
#
# WER: 100.00%
# Extracted: VA
# Ground Truth: A Sergeant and twelve mens_cm to be
#
# WER: 150.00%
# Extracted: - & ad Op 4 Sy wn 4 » uN % as xe eo Ay,
# Ground Truth: in readines_ss to escort a waggon up to Winchester tos_mi
#
# WER: 100.00%
# Extracted: a
# Ground Truth: morrows_pt
#
# WER: 187.50%
# Extracted: J a ra % J N CS : aN S yg Ww » » S
# Ground Truth: s_1s_1ths_pt To Sergeant Campbells_cm of the Virginia Regiments_pt
#
# WER: 187.50%
# Extracted: "Z x et “eo Lh y t, Oh, 2. <) “oy «\ a x A
# Ground Truth: You are to be particularly careful of the
#
# WER: 100.00%
# Extracted: ‘at QQ, Y ee as, cm “y foe ne t Pp,
# Ground Truth: Waggons s_etcs_pt under your charges_cm and are to see that centis_mi
#
# WER: 109.09%
# Extracted: & } SS rg S ASS Ny q & wt > rou
# Ground Truth: nels are kept over thems_pt If any just complaint is made
#
# WER: 166.67%
# Extracted: 7) %, af Ay , SS a 2 fA 5, <> Ds Soy 1g J?
# Ground Truth: of the misbehaviour of the party under your commands_cm
#
# WER: 172.73%
# Extracted: 4. ? <2 ge 4, te, o>, ao aN To my , Ly aN 5, s 4p ah Ck,
# Ground Truth: upon their marchs_cm you will be punished by a Court Mars_mi
#
# WER: 133.33%
# Extracted: iz re 7 = 2 - =~" a, 2 ae ~ = = a a> a
# Ground Truth: tial s_mis_pt You are to see that the waggoners do not loiter
#
# WER: 100.00%
# Extracted: , a - in nn a > Mog) |
# Ground Truth: or idle their times_sq but make the utmost dispatch to
#
# WER: 144.44%
# Extracted: ay t oN  a  pag a ar aft a™ a 44 nd axe
# Ground Truth: Winchesters_pt So soon as you arrive at Winchesters_cm you
#
# WER: 150.00%
# Extracted: SS < <* & Sy; x & RS a aS 24 rs = &> -&
# Ground Truth: are to deliver the things to the Commis_ssary theres_cm and
#
# WER: 100.00%
# Extracted: ~ ~, YY ~ x ss
# Ground Truth: are to take his receipt for thems_pt
#
# WER: 160.00%
# Extracted: x at 3 & GS ee as ey EN
# Ground Truth: Given at Alexandrias_cm s_etcs_pt December
#
# WER: 100.00%
# Extracted: oN
# Ground Truth: s_1s_1ths_pt s_1s_7s_5s_5s_pt
#
# WER: 125.00%
# Extracted: sf we AN a RY
# Ground Truth: s_GW Aide de camps_pt
#
# WER: 133.33%
# Extracted: oS en AY < A ‘ , :
# Ground Truth: s_1s_6ths_pt To Captainss_qt Savage and Mcs_ptKenzie
#
# WER: 114.29%
# Extracted: fy an ; S 7 on <Q Py
# Ground Truth: You are ordered to remain here with
#
# WER: 200.00%
# Extracted: po é. 4) F ee en 2), *, . an Ln x 7 %, 2 72) Se? ., *e, ~
# Ground Truth: your Recruits until further orderss_pt So soon as you ars_mi
#
# WER: 190.00%
# Extracted: Ee “a, ?. s ay a Cage . “y o & , >. <> a \ 3, * —
# Ground Truth: rive heres_cm your men will be supplied with Clothes by
#
# WER: 177.78%
# Extracted: ~S t a ys > ee > , St | ‘ey a y rd Sy &
# Ground Truth: applying to Major Carlyles_pt If any of your men
#
# WER: 100.00%
# Extracted: ya <S ro ai 2s Ss
# Ground Truth: should deserts_cm you are to use your utmost dilis_mi
#
# WER: 225.00%
# Extracted: SS ~~ S > =. = = ye o <5 = cs ky’ eS ss ey ~& aN,
# Ground Truth: gence in pursuing and apprehending thems_cm by ims_mi
#
# WER: 157.14%
# Extracted: ) a >, SN mH aa 2 o eS a, om
# Ground Truth: mediately advertisings_cm and sending a party or
#
# WER: 100.00%
# Extracted: y 4 v
# Ground Truth: parties after thems_pt
#
# WER: 200.00%
# Extracted: BS, ? 4 f 2 9 ‘ 4
# Ground Truth: Alexandrias_qo December s_1s_6s_cm s_1s_7s_5s_5s_pt
#
# WER: 211.11%
# Extracted: bs . 9 Ce oF, Ss 2 4 “hy, By. ea ae 24,8 Fb, 7d, &, 4, ft, An.
# Ground Truth: s_1s_6ths_pt To Ensign Buckners_pt Quarter Master to the Virginia
#
# WER: 100.00%
# Extracted: ty ay “eo iN %, » % i ey %, ve
# Ground Truth: Regiments_pt s_mi The Recruits now in this town are to res_mi
#
# WER: 100.00%
# Extracted: &, S & é s ES
# Ground Truth: s_3s_0s_8s_pt Letters Orders and Instructions December s_1s_7s_5s_5s_pt
#
# WER: 177.78%
# Extracted: Weg . Xs, Fey, “4, Pe Lo om - Von at A, Ma A “an Pn)
# Ground Truth: remain here until the arrival of the ves_ssel with
#
# WER: 180.00%
# Extracted: ors = Pan “son = & ay =<_.. xs = SX —~ x ey & 3 = =
# Ground Truth: the Storess_cm s_etcs_pt and to be under the same directions
#
# WER: 180.00%
# Extracted: if Bogs ay W- 7 ~~ g S “4g, Sa Ye, vcs 1 Tre ° & y “ie
# Ground Truth: as before ordereds_pt So soon as the Stores arrives_cm you
#
# WER: 200.00%
# Extracted: > “ * > Sy dD aN ry wk Be coy ~~ es _ a> s PS a ><
# Ground Truth: ares_cm with all pos_ssible dispaths_cm to procure a sufs_mi
#
# WER: 200.00%
# Extracted: Zz, ws ay w, “sy ? ke \ 2d ay ral ar YS he ce “Ee tf, ee,
# Ground Truth: ficient number of waggons to carry them to Wins_mi
#
# WER: 177.78%
# Extracted: 1, “2, » S ie Ly 2. LPy? ag, vs o> Lay 4, “b, Ley jae
# Ground Truth: chesters_sq whither they are to be sents_cm under the
#
# WER: 244.44%
# Extracted: en oo x I “) ad e 22, * Se coy 2 -s 4. _ ey * “> oe a > as
# Ground Truth: escort of the Soldiers now heres_qo except the Suits
#
# WER: 185.71%
# Extracted: ~ CE oo ‘ ne aw q SS rd Sg ' a re
# Ground Truth: of Clothess_sq Shoess_cm Stockings_cm Shirtss_cm s_etcs_pt proportionas_mi
#
# WER: 166.67%
# Extracted: ot é ox r> oS ~ Ee . et ss @ & o. CS ey
# Ground Truth: bly which are to be left with Colonel Carlyles_pt
#
# WER: 166.67%
# Extracted: ro ‘t, “4 Le Se wz ay) * “4, We i Lon Ay ‘ Wy
# Ground Truth: You are to be very careful of all the
#
# WER: 225.00%
# Extracted: oA “7p “ &> “be, <b aan re 4. wy, ; %, Be Ag, Ai », “ So
# Ground Truth: Things delivered into the waggonss_cm and see that
#
# WER: 230.00%
# Extracted: oy, “oO "K Pan “2 4} - “ey Ce oO . a. "L, tr. Aa, fys fy, ‘en fy. * ae Ao) «
# Ground Truth: a strict Guard is kept over thems_cm that no embezs_mi
#
# WER: 188.89%
# Extracted: Aa A ‘3 Ze we. " a a ” Sd fs wy f nA Mp, EP, Ag,
# Ground Truth: zlement is mades_pt If your men can not be
#
# WER: 200.00%
# Extracted: “2 ff, B - “k, oP ; * os, 2 ae A r Lt,
# Ground Truth: conveniently Quartered on their march ups_sq there
#
# WER: 100.00%
# Extracted: Fs LOg an v a . g uN (P> |
# Ground Truth: will be a number of Tents among the Storess_cm which
#
# WER: 154.55%
# Extracted: “t- ey “Ly Fr  , oy Ly oi \ : Cl Me # ¢ Yon SF <2
# Ground Truth: must be made use ofs_pt s_mi If any of the Soldiers
#
# WER: 130.00%
# Extracted: \ ya g IS A 4 ra P | \ NY \ |
# Ground Truth: should desert from this places_cm s_mi it would be proper
#
# WER: 150.00%
# Extracted: Zane Fi 5. +, Y, y, ~ <F a 5 ay Ly Tae LE oe ay
# Ground Truth: to send a Sergeants_cm and one or two trusty men
#
# WER: 125.00%
# Extracted: Sy “7 é Gay, -
# Ground Truth: in pursuit of thems_pt
#
# WER: 275.00%
# Extracted: 0, % ¥ A Y Cy, “le. a < af “¥,
# Ground Truth: Given at Alexandria s_etcs_pt
#
# WER: 600.00%
# Extracted: XN oy? oe > XN 08 « O&M oe) re \ cs ny * ay iy e. we
# Ground Truth: December s_1s_6ths_pt s_1s_7s_5s_5s_pt
#
# WER: 100.00%
# Extracted: ae f nA le Tt 123
# Ground Truth: s_1s_6ths_pt To Doctor James Craiks_cm of the Virginia
#
# WER: 400.00%
# Extracted: PRS Sf Se, S
# Ground Truth: Regiments_pt
#
# WER: 185.71%
# Extracted: 4 .  ge ee  is  o eo ae iy My, Ny Sy &
# Ground Truth: So soon as the Ves_ssel with the
#
# WER: 137.50%
# Extracted: %y,  4  tf,  e  1. %, <> * %, ~ a
# Ground Truth: Stores and medicines arrivess_cm you are to embrace
#
# WER: 100.00%
# Extracted: . Bs <r a uN ~ SQ.
# Ground Truth: the first opportunity that offerss_cm of conveying up
#
# WER: 100.00%
# Extracted: & & Pe Se & S Sy
# Ground Truth: your Chests_cm and proceedings_cm yourselfs_cm to Winchess_mi
#
# WER: 137.50%
# Extracted: Wa h Pr ar S on ) (  Ss  ¢  Ty
# Ground Truth: ters_pt You are to provide yourself heres_cm with
#
# WER: 100.00%
# Extracted: ta " w rg rs ? a
# Ground Truth: what you think will be wanting for the Hoss_mi
#
# WER: 100.00%
# Extracted: ey fon > % Sn
# Ground Truth: pitals_cm and bring them up with yous_sq taking
#
# WER: 100.00%
# Extracted: S = sy : & SS. &
# Ground Truth: care to purchase no more than is absolutely
#
# WER: 122.22%
# Extracted: yo ay ; XX ye x 4 “3 ry » S
# Ground Truth: neces_ssarys_cm for the support and relief of the Regiment
#
# WER: 100.00%
# Extracted:
# Ground Truth: ps_pts_3s_0s_9s_pt
#
# WER: 133.33%
# Extracted: On eG “ e Lay eZ) % Fy,
# Ground Truth: Letters Orders and Instructions December s_1s_7s_5s_5s_pt
#
# WER: 150.00%
# Extracted: *y, iy A. Q® 2 N
# Ground Truth: Given at Alexandria s_etcs_pt
#
# WER: 300.00%
# Extracted: A aN Ma tn d “hy 3 co te
# Ground Truth: December s_1s_6ths_pt s_1s_7s_5s_5s_pt
#
# WER: 100.00%
# Extracted: ae 1% SS ng a :
# Ground Truth: s_1s_6ths_pt To Captain John Mercers_pt of the
#
# WER: 200.00%
# Extracted: On) My an iy.
# Ground Truth: Virginia Regiments_pt
#
# WER: 100.00%
# Extracted: ro gp Ne a ks
# Ground Truth: You are immediatelys_cm upon receipt
#
# WER: 100.00%
# Extracted: Ke oP Q ‘eb. Ly, i, “oN BD ‘
# Ground Truth: hereofs_cm to repair to Winchesters_cm where you will meet
#
# WER: 114.29%
# Extracted: PS rg ES ( ON yi re rc
# Ground Truth: with Colonel Washingtons_cm and receive further orderss_pt
#
# WER: 100.00%
# Extracted: Se
# Ground Truth: I am s_etcs_pt
#
# WER: 275.00%
# Extracted: Y2>, eH 7% ob) nr My ~ . x “ os
# Ground Truth: s_GW aid de camps_pt
#
# WER: 100.00%
# Extracted: ae ec no =
# Ground Truth: Alexandrias_qo December s_1s_6ths_pt s_1s_7s_5s_5s_pt
#
# WER: 150.00%
# Extracted: Vie - Y e a fs, ty, ayy Yn i My |
# Ground Truth: Ns_qoBs_pt A Copy left at Alexandrias_cm and another
#
# WER: 116.67%
# Extracted: eo ~> aS ae Da ok er
# Ground Truth: sent to Staffords_cm to him theres_pt
#
# WER: 228.57%
# Extracted: wy r a rs = a 5 3 og we Ai he 3h p ee ESy
# Ground Truth: s_2s_0ths_pt Parole Abbemarles_pt Winchesters_qo December s_2s_0ths_pt s_1s_7s_5s_5s_pt
#
# WER: 100.00%
# Extracted: ya
# Ground Truth: A Return to be given in immedis_mi
#
# WER: 90.91%
# Extracted: 1 : Pry, <<“ in ” hy <>, { in,
# Ground Truth: ately of the Recruits now in this towns_cm by the several
#
# WER: 100.00%
# Extracted: Sy & ey S i | wg
# Ground Truth: Officers who enlisted thems_sq mentioning their heights_cm
#
# WER: 110.00%
# Extracted: P wee sR oe » ce Se aoe wt at S
# Ground Truth: ages_cm trades_cm s_etcs_pt The officers to see that the Serges_mi
#
# WER: 185.71%
# Extracted: ty te oe Fy 7h Sy Lt os Fe Oy ou of ty
# Ground Truth: ants who understand the manual Exercises_cm do
#
# WER: 114.29%
# Extracted: \ % in oy, LE eo “ Pe,
# Ground Truth: drill the Recruitss_cm at least twice as_midays_pt
#
# WER: 285.71%
# Extracted: ©, ¥ as p < \ ; . , iN sw wv “ “ ° ; P , 3 y
# Ground Truth: s_2s_2nds_pt Parole Bostons_mi Winchesters_qo December s_2s_2nds_pt s_1s_7s_5s_5s_pt
#
# WER: 100.00%
# Extracted: . at Dx, t. 2 2
# Ground Truth: A Return is to be made every mors_mi
#
# WER: 100.00%
# Extracted: iy re LS sy rg a e ee
# Ground Truth: ning to Colonel Washington of the number of
#
# WER: 100.00%
# Extracted: on gr Kv, “et fre
# Ground Truth: men in this town s_mi and all contingencess_pt
#
# WER: 110.00%
# Extracted: 7, fy Le  fy fy, “A  - E, v4 On PD.
# Ground Truth: During his stay heres_cm no provision is to be des_mi
#
# WER: 90.00%
# Extracted: Bs ED aN a . 2, %, Ls oD,
# Ground Truth: livered outs_cm but by a written order from him or
#
# WER: 133.33%
# Extracted: ey 7 o> Cf 0 rn es) - fA. x . 4,
# Ground Truth: the aid de camps_pt The Commis_ssary is to send
#
# WER: 150.00%
# Extracted: ey es wh M5 es Be, x ™ ‘\ tX & oe = # :
# Ground Truth: up the Cask of Tools by the first waggon that
#
# WER: 144.44%
# Extracted: ry << < eK og « erg re 2 a  s ak -
# Ground Truth: goes to the Forts_pt The following men being judgs_mi
#
# WER: 110.00%
# Extracted: x . SS a? ¢ a J rk &, &x ees
# Ground Truth: ed unfit for Dutys_cm on Reviews_sq are ordered to be
#
# WER: 100.00%
# Extracted: y
# Ground Truth: dischargeds_qo vizs_pt
