# %%
import os
from PIL import Image, ImageFilter
import numpy as np
import random

# Binarization
def binarize_image(image):
    img = image.convert('L')  # Convert image to grayscale
    # Binarize using a threshold
    threshold = 128
    binary_img = img.point(lambda p: 255 if p > threshold else 0)
    return binary_img

# Deskewing
def deskew_image(image):
    # Convert to NumPy array
    img_array = np.array(image)

    # Find the coordinates of the black (non-background) pixels
    coords = np.column_stack(np.where(img_array == 0))
    if len(coords) == 0:
        return image  # If there are no black pixels, return the original image

    # Calculate the angle of skew
    angle = np.rad2deg(np.arctan2(coords[:, 1].mean() - img_array.shape[0] / 2, coords[:, 0].mean() - img_array.shape[1] / 2))

    if angle < -45:
        angle = -(90 + angle)
    else:
        angle = -angle

    # Rotate the image
    pil_image = image.rotate(angle, expand=True)  # Use PIL to rotate
    return pil_image

# Noise removal
def remove_noise(image):
    # Apply a Gaussian blur to reduce noise
    denoised_image = image.filter(ImageFilter.GaussianBlur(radius=1))
    return denoised_image

# Preprocess an image
def preprocess_image(img):
    if isinstance(img, str):  # If the input is a file path, open the image
        img = Image.open(img)

    # Binarize the image (assuming this function is defined)
    binary_img = binarize_image(img)

    # Deskew the image (assuming this function is defined)
    deskewed_img = deskew_image(binary_img)

    # Resize the image to a fixed size (for example 1024x1024)
    resized_img = deskewed_img.resize((1024, 1024))

    return resized_img

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
from PIL import Image, ImageEnhance, ImageFilter
import numpy as np
import random

# Load and preprocess data
def load_washington_data(images_folder, transcription_file):
    images = []
    transcriptions = []

    # Load images as PIL Image objects
    for filename in os.listdir(images_folder):
        if filename.endswith('.png'):
            img_path = os.path.join(images_folder, filename)
            img = Image.open(img_path)  # Open image using PIL
            images.append(img)

    # Load transcriptions
    with open(transcription_file, 'r') as f:
        transcriptions = [line.strip() for line in f.readlines()]

    return images, transcriptions

import random
from PIL import Image, ImageEnhance
from torchvision import transforms

# Define the AdvancedAugmentation class
class AdvancedAugmentation:
    def __init__(self):
        self.transforms = transforms.Compose([
            transforms.RandomRotation(15),  # Rotate images randomly within a 15-degree range
            transforms.RandomHorizontalFlip(),
            transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2),  # Randomly change brightness, contrast, saturation, and hue
            transforms.RandomAffine(translate=(0.1, 0.1), degrees=10, shear=10)  # Random affine transformations
        ])

    def __call__(self, img):
        return self.transforms(img)

# Function to augment images
def augment_images_with_labels(images, transcriptions):
    augmented_images = []
    augmented_transcriptions = []

    # Initialize the advanced augmentation
    augmentation = AdvancedAugmentation()

    for img, transcription in zip(images, transcriptions):
        augmented = augmentation(img)  # Apply the advanced augmentation to the image
        augmented_images.append(augmented)
        augmented_transcriptions.append(transcription)  # Keep the original transcription for augmented image

    return augmented_images, augmented_transcriptions



# Split the data into train, validation, and test sets
def split_data(images, transcriptions, train_ratio=0.7, val_ratio=0.15):
    total_size = len(images)
    indices = list(range(total_size))
    random.shuffle(indices)

    train_size = int(total_size * train_ratio)
    val_size = int(total_size * val_ratio)

    train_indices = indices[:train_size]
    val_indices = indices[train_size:train_size + val_size]
    test_indices = indices[train_size + val_size:]

    train_images = [images[i] for i in train_indices]
    train_transcriptions = [transcriptions[i] for i in train_indices]

    val_images = [images[i] for i in val_indices]
    val_transcriptions = [transcriptions[i] for i in val_indices]

    test_images = [images[i] for i in test_indices]
    test_transcriptions = [transcriptions[i] for i in test_indices]

    return (train_images, train_transcriptions), (val_images, val_transcriptions), (test_images, test_transcriptions)

# %%
# !pip install pytesseract
# Out:
# Collecting pytesseract
#   Downloading pytesseract-0.3.13-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (24.2)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (11.0.0)
# Downloading pytesseract-0.3.13-py3-none-any.whl (14 kB)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.13

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models

def modify_resnet_for_grayscale(resnet_model):
    # Modify the first convolutional layer of ResNet-18 to accept 1 channel
    resnet_model.conv1 = nn.Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
    return resnet_model

class OCRModel(nn.Module):
    def __init__(self, num_classes, hidden_size=128, num_layers=2, dropout_rate=0.5):
        super(OCRModel, self).__init__()

        # Load ResNet-18 and modify it for grayscale input
        resnet = models.resnet18(pretrained=True)
        resnet = modify_resnet_for_grayscale(resnet)  # Modify ResNet for grayscale

        # Freeze the parameters in the ResNet layers except the final layer
        for name, param in resnet.named_parameters():
            if 'conv1' not in name:
                param.requires_grad = False

        # Remove the fully connected layer from ResNet
        self.feature_extractor = nn.Sequential(*list(resnet.children())[:-2])

        self.combining_conv = nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1)
        self.batch_norm = nn.BatchNorm2d(512)  # Add BatchNorm
        self.relu = nn.ReLU()
        self.pooling = nn.AdaptiveAvgPool2d((32, 32))  # Further reduces dimensions

        # Dropout after feature extraction and convolution
        self.feature_dropout = nn.Dropout2d(dropout_rate)  # Dropout for 2D features

        # Sequence modeling using LSTM
        self.rnn = nn.LSTM(input_size=512, hidden_size=hidden_size, num_layers=num_layers, batch_first=True, dropout=dropout_rate)

        # Dropout after LSTM
        self.rnn_dropout = nn.Dropout(dropout_rate)

        self.fc = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        # Extract features using ResNet
        features = self.feature_extractor(x)
        features = F.normalize(features, p=2, dim=1)  # Normalize features

        features = F.interpolate(features, size=(128, 128), mode="bilinear", align_corners=False)
        features = self.combining_conv(features)
        features = self.batch_norm(features)  # Batch normalization
        features = self.relu(features)
        features = self.pooling(features)  # Reduce spatial dimensions

        # Apply dropout after the feature extraction
        features = self.feature_dropout(features)

        # Reshape features for LSTM input
        B, C, H, W = features.size()
        features = features.view(B, H * W, C)

        # Sequence modeling with LSTM
        rnn_out, _ = self.rnn(features)

        # Apply dropout after LSTM
        rnn_out = self.rnn_dropout(rnn_out)

        # Classify with a fully connected layer
        logits = self.fc(rnn_out)

        return logits

# Example usage:
num_classes = 97  # Adjust to your specific number of classes
model = OCRModel(num_classes=num_classes, dropout_rate=0.5)  # Set dropout rate as needed

# Example input (batch_size, channels, height, width)
input_tensor = torch.randn(16, 1, 128, 128)  # Batch size of 16, grayscale images of 128x128

# Forward pass
output = model(input_tensor)
print(output.shape)  # Should output (batch_size, sequence_length, num_classes)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 167MB/s]
# torch.Size([16, 1024, 97])

# %%
import os
from PIL import Image
import numpy as np
import torch
import torch.nn as nn
import torchvision.transforms as transforms
from torchvision import models
from sklearn.model_selection import train_test_split

# Main workflow
images_folder = '/content/drive/My Drive/washingtondb-v1.0/data/line_images_normalized'
transcription_file = '/content/drive/My Drive/washingtondb-v1.0/ground_truth/transcription.txt'

# Load data
images, transcriptions = load_washington_data(images_folder, transcription_file)

# Preprocess images
preprocessed_images = [preprocess_image(img) for img in images]

# Augment data
augmented_images, augmented_transcriptions = augment_images_with_labels(preprocessed_images, transcriptions)
all_images = preprocessed_images + augmented_images
all_transcriptions = transcriptions * 2  # Duplicate transcriptions for augmented data

# Split data
(train_images, train_transcriptions), (val_images, val_transcriptions), (test_images, test_transcriptions) = split_data(all_images, all_transcriptions)

# %%
import torch
import numpy as np
import cv2
from torch.utils.data import Dataset
from torchvision import transforms
from PIL import Image

class CroppedImagesDataset(Dataset):
    def __init__(self, images, targets, transform=None):
        """
        Args:
            images (list): List of file paths or PIL Image objects.
            targets (list): List of transcription strings (labels).
            transform (callable, optional): Optional transforms to be applied to images.
        """
        self.images = images
        self.targets = targets
        self.transform = transform or transforms.Compose([
            transforms.Resize((128, 128)),  # Resize to 128x128
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.5], std=[0.5])
        ])

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        # If the image is already a PIL Image, skip opening it
        image = self.images[idx]
        if not isinstance(image, Image.Image):
            image = Image.open(image).convert("L")  # Open as grayscale if not already PIL

        # Apply the transform
        if self.transform:
            image = self.transform(image)

        target = self.targets[idx]
        return image, target


# Step 1: Define a custom collate_fn
def collate_fn(batch):
    images, targets = zip(*batch)

    # Stack the images to create a batch (torch.stack assumes all images are the same shape)
    images_stack = torch.stack(images)

    # Use the encode_target function to encode the target strings
    encoded_targets, target_lengths = encode_target(targets)

    # Stack the targets (now they're tensors of indices)
    targets_stack = torch.nn.utils.rnn.pad_sequence(encoded_targets, batch_first=True, padding_value=char_to_index['<blank>'])

    return images_stack, targets_stack


# Assuming segmented_images and targets are already defined
train_dataset = CroppedImagesDataset(train_images, train_transcriptions)
val_dataset = CroppedImagesDataset(val_images, val_transcriptions)
test_dataset = CroppedImagesDataset(test_images, test_transcriptions)

# Create a DataLoader for batching
from torch.utils.data import DataLoader

batch_size = 16  # Adjust based on your system's capacity


data_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# Function to display a batch of images and their labels

# Create DataLoaders

# %%
import string

# Generating all printable ASCII characters (from 32 to 126 inclusive)
ascii_chars = [chr(i) for i in range(32, 127)]

# Add non-printable but commonly used ASCII characters (e.g., newline '\n')
special_chars = ['\n']

# Combine special and printable characters into the vocabulary
vocab = ['<blank>'] + ascii_chars + special_chars

# Create mapping dictionaries
char_to_index = {char: idx for idx, char in enumerate(vocab)}
index_to_char = {idx: char for idx, char in enumerate(vocab)}

# Print the index of <blank> token and the size of the vocabulary
print(f"Index of <blank>: {char_to_index['<blank>']}")
print(f"Size of vocabulary: {len(vocab)}")
# Out:
# Index of <blank>: 0
# Size of vocabulary: 97

# %%
def encode_target(target_texts):
    encoded_targets = []  # List to hold encoded target texts (as tensors)
    target_lengths = []   # List to hold lengths of each encoded target text
    unknown_chars = []    # List to hold characters that are not found in the vocabulary

    for text in target_texts:
        text = str(text)  # Ensure text is a string
        encoded_text = []  # List to hold indices for the current text

        for char in text:
            if char in char_to_index:
                # Directly map the character to its index if it exists in vocab
                encoded_text.append(char_to_index[char])
            else:
                # If the character is not found, use <blank> token
                encoded_text.append(char_to_index['<blank>'])
                unknown_chars.append(char)  # Track unknown characters

        # Append the encoded text as a PyTorch tensor of long integers
        encoded_targets.append(torch.tensor(encoded_text, dtype=torch.long))

        # Append the length of the current encoded text
        target_lengths.append(len(encoded_text))

    # Optionally, log unknown characters for debugging purposes
    if unknown_chars:
        print(f"Unknown characters encountered: {set(unknown_chars)}")

    return encoded_targets, target_lengths

# %%
# Example target texts (strings)
target_texts = ["Hello", "World", "Test"]

# Encode target texts
encoded_targets, target_lengths = encode_target(target_texts)
print(encoded_targets)

# Print encoded outputs
for idx, encoded_text in enumerate(encoded_targets):
    print(f"Text: {target_texts[idx]}, Encoded: {encoded_text}, Length: {target_lengths[idx]}")
# Out:
# [tensor([41, 70, 77, 77, 80]), tensor([56, 80, 83, 77, 69]), tensor([53, 70, 84, 85])]
# Text: Hello, Encoded: tensor([41, 70, 77, 77, 80]), Length: 5
# Text: World, Encoded: tensor([56, 80, 83, 77, 69]), Length: 5
# Text: Test, Encoded: tensor([53, 70, 84, 85]), Length: 4

# %%
import torch

# Example mapping of indices to characters


def decoding_target(encoded_tensors):
    decoded_texts = []

    for encoded_tensor in encoded_tensors:
        # Convert tensor to list of integers
        encoded_list = encoded_tensor.tolist()
        # Decode each index to a character
        decoded_text = ''.join([index_to_char.get(idx, '?') for idx in encoded_list])
        # Append the decoded string to the result
        decoded_texts.append(decoded_text)

    return decoded_texts

# Example usage
# Use a list of tensors for variable-length sequences
encoded_targets = [torch.tensor([40, 69, 76, 76, 79]), torch.tensor([55, 79, 82, 76, 68]), torch.tensor([52, 69, 83, 84])]


decoded_texts = decoding_target(encoded_targets)
print(decoded_texts)
# Out:
# ['Gdkkn', 'Vnqkc', 'Sdrs']

# %%
# !pip install torchmetrics
# Out:
# Collecting torchmetrics
#   Downloading torchmetrics-1.6.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (1.26.4)
# Requirement already satisfied: packaging>17.1 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (24.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (2.5.1+cu121)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics)
#   Downloading lightning_utilities-0.11.9-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (75.1.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (4.12.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->torchmetrics) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->torchmetrics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->torchmetrics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->torchmetrics) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->torchmetrics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=2.0.0->torchmetrics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.0.0->torchmetrics) (3.0.2)
# Downloading torchmetrics-1.6.0-py3-none-any.whl (926 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 926.4/926.4 kB 16.5 MB/s eta 0:00:00
# Downloading lightning_utilities-0.11.9-py3-none-any.whl (28 kB)
# Installing collected packages: lightning-utilities, torchmetrics
# Successfully installed lightning-utilities-0.11.9 torchmetrics-1.6.0

# %%
num_classes = len(vocab)
print(num_classes)
# Out:
# 97

# %%
def validate(model, validation_loader, criterion):
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for images, labels in validation_loader:
            images = images.to(device)
            targets, target_lengths = encode_target(labels)
            targets = torch.nn.utils.rnn.pad_sequence(
                targets, batch_first=True, padding_value=char_to_index['<blank>']
            ).to(device)

            logits = model(images)
            logits = torch.clamp(logits, min=-10, max=10)
            input_lengths = torch.full(
                (images.size(0),), logits.size(1), dtype=torch.long
            ).to(device)
            target_lengths = torch.tensor(target_lengths, dtype=torch.long).to(device)
            log_probs = F.log_softmax(logits, dim=-1)

            loss_value = criterion(
                log_probs.permute(1, 0, 2),  # [T, N, C] for CTC
                targets,
                input_lengths,
                target_lengths,
            )
            val_loss += loss_value.item()

    return val_loss / len(validation_loader)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchmetrics.text import WordErrorRate  # WER metric
import time
import torch.nn.functional as F
from torch.optim.lr_scheduler import ReduceLROnPlateau


# Define the device (CUDA if available, else CPU)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Feature extractor and OCR model
num_classes = len(vocab)

# Initialize the OCR model with both U-Net and ResNet
ocr_model = OCRModel(num_classes).to(device)

# Loss and optimizer
criterion = nn.CTCLoss(blank=char_to_index['<blank>']).to(device)  # CTC loss
optimizer = optim.Adam(ocr_model.parameters(), lr=1e-3)
scheduler = ReduceLROnPlateau(optimizer, 'min', patience=3, factor=0.5)


best_val_loss = float('inf')  # Initialize to infinity


# Train the OCR model
def train_ocr_model(model, dataloader, validation_loader, loss, optimizer, num_epochs=10):
    model.train()
    for epoch in range(num_epochs):
        epoch_loss = 0.0
        for batch_idx, (images, labels) in enumerate(dataloader):

            # Input validation

            images = images.to(device)

            # Encode targets
            targets, target_lengths = encode_target(labels)
            targets = torch.nn.utils.rnn.pad_sequence(
                targets, batch_first=True, padding_value=char_to_index['<blank>']
            ).to(device)

            optimizer.zero_grad()

            # Forward pass
            logits = model(images)  # Output shape: [B, W, num_classes]

            # Clamp logits to stabilize training
            logits = torch.clamp(logits, min=-10, max=10)
            # Define lengths
            input_lengths = torch.full(
                (images.size(0),), logits.size(1), dtype=torch.long
            ).to(device)  # Sequence length
            target_lengths = torch.tensor(target_lengths, dtype=torch.long).to(device)

            # Compute log probabilities for CTC
            log_probs = F.log_softmax(logits, dim=-1)

            # Loss computation with exception handling
            try:
                loss_value = loss(
                    log_probs.permute(1, 0, 2),  # [T, N, C] for CTC
                    targets,
                    input_lengths,
                    target_lengths,
                )
                if torch.isnan(loss_value) or torch.isinf(loss_value):
                    print("NaN or Inf detected in loss. Skipping batch.")
                    continue

                # Backpropagation
                loss_value.backward()
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
                optimizer.step()

                epoch_loss += loss_value.item()

            except Exception as e:
                print(f"Error during loss computation: {e}. Skipping batch.")
                continue
        model.eval()
        val_loss = validate(model, validation_loader, loss)
        scheduler.step(val_loss)
        print(f"Epoch {epoch + 1}/{num_epochs}, Average Train Loss: {epoch_loss / len(dataloader):.4f}, Total Train Loss: {epoch_loss:.4f}, Validation Loss: {val_loss:.4f}")

        # Save the best model
        global best_val_loss
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), "best_ocr_model.pth")
            print("Best model saved!")

        model.train()

# Train the model
train_ocr_model(ocr_model, data_loader, val_loader, criterion, optimizer)

# Save model weights after training
torch.save(ocr_model.state_dict(), "final_ocr_model.pth")
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/10, Average Train Loss: 2.9478, Total Train Loss: 170.9701, Validation Loss: 14.9772
# Best model saved!
# Epoch 2/10, Average Train Loss: 2.0626, Total Train Loss: 119.6318, Validation Loss: 14.8991
# Best model saved!
# Epoch 3/10, Average Train Loss: 2.0455, Total Train Loss: 118.6411, Validation Loss: 17.1279
# Epoch 4/10, Average Train Loss: 2.0086, Total Train Loss: 116.4962, Validation Loss: 19.9591
# Epoch 5/10, Average Train Loss: 1.9643, Total Train Loss: 113.9300, Validation Loss: 17.4745
# Epoch 6/10, Average Train Loss: 1.9128, Total Train Loss: 110.9444, Validation Loss: 17.2562
# Epoch 7/10, Average Train Loss: 1.8651, Total Train Loss: 108.1760, Validation Loss: 21.7246
# Epoch 8/10, Average Train Loss: 1.8672, Total Train Loss: 108.2996, Validation Loss: 18.3433
# Epoch 9/10, Average Train Loss: 1.8320, Total Train Loss: 106.2559, Validation Loss: 17.7067
# Epoch 10/10, Average Train Loss: 1.8283, Total Train Loss: 106.0412, Validation Loss: 21.2786

# %%
# Decode target indices back to text
def decode_target(target):
    return ''.join([index_to_char[idx.item()] for idx in target if idx.item() != char_to_index['<blank>']])

# %%
import editdistance

def calculate_cer(pred_texts, target_texts):
    """
    Calculate the Character Error Rate (CER) between predicted and target texts.
    CER = Levenshtein Distance / Number of characters in the target text.
    """
    total_cer = 0
    total_chars = 0

    for pred, target in zip(pred_texts, target_texts):
        # Levenshtein distance
        edit_dist = editdistance.eval(pred, target)
        total_cer += edit_dist
        total_chars += len(target)

    cer = total_cer / total_chars if total_chars > 0 else 0
    return cer

# %%
import torch
import torch.nn.functional as F
from torchmetrics import WordErrorRate
from torch.nn.utils.rnn import pad_sequence

def evaluate(model, loader):
    model.eval()
    wer_metric = WordErrorRate()
    temperature =  1 # You can adjust this value based on experimentation

    with torch.no_grad():
        for images, labels in loader:
            images = images.to(device)

            # Encode the labels using your encode_target function
            targets, target_lengths = encode_target(labels)

            # Pad the targets and move to device
            targets = pad_sequence(targets, batch_first=True, padding_value=char_to_index['<blank>']).to(device)
            target_lengths = torch.tensor(target_lengths, dtype=torch.long).to(device)  # Convert list to tensor and move to device

            # Forward pass through the model
            logits = model(images)

            # Apply softmax with temperature scaling (logits are of shape [batch_size, seq_len, num_classes])
            probs = torch.softmax(logits / temperature, dim=-1)  # Apply temperature to logits

            # Get the most probable character indices
            pred_indices = torch.argmax(probs, dim=-1)  # shape (batch_size, sequence_length)

            # Convert indices to characters (ensure you have a mapping from indices to characters)
            predicted_texts = []
            for indices in pred_indices:
                predicted_text = ''.join([vocab[i.item()] for i in indices])
                predicted_texts.append(predicted_text)

            # Decode the target labels to text
            target_strings = [decode_target(target) for target in targets]  # Process each target sequence

            # Print out the predictions and targets
            for pred, target in zip(predicted_texts, target_strings):
                print(f"Predicted: {pred}")
                print(f"Ground Truth: {target}")
                print("-" * 50)

            cer = calculate_cer(decoded_texts, target_strings)
            print(f"CER: {cer:.2f}")

            # Use WER metric (works with strings now)
            wer = wer_metric(predicted_texts, target_strings)
            print(f"WER: {wer.item():.2f}")

# Assuming you have a model and a test loader
evaluate(ocr_model, test_loader)  # This would call the evaluate function with your OCR model and test loader
# Out:
# /usr/local/lib/python3.10/dist-packages/torchmetrics/utilities/prints.py:62: FutureWarning: Importing `WordErrorRate` from `torchmetrics` was deprecated and will be removed in 2.0. Import `WordErrorRate` from `torchmetrics.text` instead.
#   _future_warning(
# Predicted: tennsoor(([[2<blank>,,,,,,,,,,,,,,,,,,,,,,,,,,      <blank><blank>   <blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank> ...
# Ground Truth: 277-21 Y-o-u|a-r-e|h-e-r-e-b-y|o-r-d-e-r-e-d-s_cm|a-s|s-o-o-n|a-s
# --------------------------------------------------
# Predicted: tennssorr(([[2<blank>,,,    ,,,,,,,,,,,,,,,       <blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blan ...
# Ground Truth: 277-32 o-r|a-n-y|o-t-h-e-r-s-s_cm|s_mi|o-r|P-l-a-n-t-a-t-i-o-n-s-s_pt|s_mi|L-i-e-u-t-e-n-a-n-t|F-r-a-s_mi
# --------------------------------------------------
# Predicted: tennssorr([[[2,,,     ,,,,,,,,,,,,,,        <blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><bla ...
# Ground Truth: 276-07 h-a-v-e|C-a-t-t-l-e|d-e-l-i-v-e-r-e-d|h-e-r-e|s_et-c-s_pt|b-y|t-h-e|s_1st-s_pt|o-f|n-e-x-t
# --------------------------------------------------
# Predicted: tennssorr([[[2,,,     ,,,,,,,,,,,,,,        <blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><bla ...
# Ground Truth: 273-25 t-h-e|m-e-n|c-o-m-p-l-e-t-e-l-y|f-u-r-n-i-s-h-e-d|w-i-t-h|b-o-t-h-s_sq|a-n-d
# --------------------------------------------------
# Predicted: tennssoor(([[2<blank>,,,    ,,,,,,,,,,,,,,,       <blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blan ...
# Ground Truth: 302-04 s-m-a-l-l|d-u-r-a-t-i-o-n-s_pt|W-e|s-h-a-l-l|a-l-s-o|i-n|a|l-i-t-t-l-e|t-i-m-e-s_cm
# --------------------------------------------------
# Predicted: tennssorr(([[2,,,     ,,,,,,,,,,,,,,,       <blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><bla ...
# Ground Truth: 274-15 h-i-m|i-m-m-e-d-i-a-t-e-l-y-s_pt|I-f|n-o|o-t-h-e-r|H-o-r-s-e-s-s_cm|b-e-l-o-n-g-s_mi
# --------------------------------------------------
# Predicted: teennsoor(([[2<blank>,,,     ,,,,,,,,,,,,,,,     <blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank ...
# Ground Truth: 303-31 o-f|t-h-e-m|a-r-e|a-c-q-u-a-i-n-t-e-d|t-h-a-t|s-u-c-h|a|L-a-w|e-x-i-s-t-s-s_qo|a-n-d
# --------------------------------------------------
# Predicted: tennssorr([[[2,,,     ,,,,,,,,,,,,,,        <blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><bla ...
# Ground Truth: 275-28 o-f|P-o-r-k|a-s|y-o-u|i-m-a-g-i-n-e|w-i-l-l|b-e|n-e-c-e-s_s-s-a-r-y|f-o-r|t-h-e
# --------------------------------------------------
# Predicted: tennsorr(([[2<blank>,,      ,,,,,,,,,,,,,,,,      <blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blan ...
# Ground Truth: 278-10 N-o-v-e-m-b-e-r|s_1st-s_pt|s_1-s_7-s_5-s_5-s_pt
# --------------------------------------------------
# Predicted: tennssorr([[[2,,,     ,,,,,,,,,,,,,,,      <blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blan ...
# Ground Truth: 308-10 o-f|C-l-o-t-h-e-s-s_sq|S-h-o-e-s-s_cm|S-t-o-c-k-i-n-g-s_cm|S-h-i-r-t-s-s_cm|s_et-c-s_pt|p-r-o-p-o-r-t-i-o-n-a-s_mi
# --------------------------------------------------
# Predicted: tennssorr([[[2,,,     ,,,,,,,,,,,,,         <blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><bla ...
# Ground Truth: 308-28 S-t-o-r-e-s|a-n-d|m-e-d-i-c-i-n-e-s|a-r-r-i-v-e-s-s_cm|y-o-u|a-r-e|t-o|e-m-b-r-a-c-e
# --------------------------------------------------
# ...
# Ground Truth: 276-26 L-i-e-u-t-e-n-a-n-t|K-i-n-g-s_cm|a-n-d|b-e|u-n-d-e-r|h-i-s|c-o-m-m-a-n-d
# --------------------------------------------------
# Predicted: tennssorr([[[2,,,     ,,,,,,,,,,,,,         <blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><bla ...
# Ground Truth: 303-16 w-o-u-l-d|f-i-x|i-t-s_qo|s-o|i-s|C-a-p-t-a-i-n|S-t-e-w-a-r-t-s-s_qo|I-f|C-a-p-t-a-i-n|S-t-e-w-s_mi
# --------------------------------------------------
# Predicted: tennssorr(([[2,,,     ,,,,,,,,,,,,,,,       <blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><bla ...
# Ground Truth: 275-06 a-n-d|t-h-a-t|t-h-e-y|a-r-e|p-r-a-c-t-i-s-e-d|a-l-s-o|i-n|s-h-o-o-t-i-n-g|a-t|T-a-r-s_mi
# --------------------------------------------------
# Predicted: tennssorr([[[2,,,     ,,,,,,,,,,,,,         <blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><blank><bla ...
# Ground Truth: 271-08 w-i-t-h-o-u-t|a|S-u-r-g-e-o-n-s_cm|i-f|y-o-u|w-i-l-l|d-o|t-h-a-t|d-u-t-y-s_cm|a-n
# --------------------------------------------------
# CER: 0.98
# WER: 1.50

# %%
output_file = "/content/drive/My Drive/justresnetall.txt"

def process_transcription_and_save_separately(transcription_output, output_file):
    """
    Save all transcription outputs into a single text file.

    Args:
        transcription_output (list): A list of transcription strings.
        output_file (str): The file where all transcriptions will be saved.
    """
    with open(output_file, 'w') as f:
        for idx, line in enumerate(transcription_output):
            f.write(line)
    print(f"All transcriptions saved to {output_file}")

# %%
import torch
import torch.nn.functional as F
from torchmetrics import WordErrorRate
from torch.nn.utils.rnn import pad_sequence

def decode_ctc(logits, char_to_index, index_to_char):
    batch_size = logits.size(0)
    seq_len = logits.size(1)

    if logits.dim() == 2:  # Shape (batch_size, seq_len)
        pred_indices = logits  # Assuming logits are already the predicted class indices
    elif logits.dim() == 3:
        _, pred_indices = logits.max(dim=-1)  # Get indices with highest probability (batch_size, seq_len)
    else:
        raise ValueError("Unexpected logits shape")

    decoded_texts = []
    for batch_idx in range(batch_size):
        text = []
        prev_idx = -1

        for seq_idx in range(seq_len):
            idx = pred_indices[batch_idx, seq_idx].item()  # Convert to Python integer

            # Skip <blank> and consecutive duplicates
            if idx != char_to_index['<blank>'] and idx != prev_idx:
                text.append(index_to_char[idx])  # Convert index to character
            prev_idx = idx

        decoded_texts.append(''.join(text))

    return decoded_texts


def evaluate(model, loader, vocab, char_to_index, index_to_char):
    model.eval()
    wer_metric = WordErrorRate()
    temperature =  1  # You can adjust this value based on experimentation

    with torch.no_grad():
        for images, labels in loader:
            images = images.to(device)

            # Encode the labels using your encode_target function
            targets, target_lengths = encode_target(labels)

            # Pad the targets and move to device
            targets = pad_sequence(targets, batch_first=True, padding_value=char_to_index['<blank>']).to(device)
            target_lengths = torch.tensor(target_lengths, dtype=torch.long).to(device)  # Convert list to tensor and move to device

            # Forward pass through the model
            logits = model(images)

            # Apply softmax with temperature scaling (logits are of shape [batch_size, seq_len, num_classes])
            probs = torch.softmax(logits / temperature, dim=-1)  # Apply temperature to logits


            # Decode the logits using CTC decoding
            decoded_texts = decode_ctc(probs, char_to_index, index_to_char)  # Using decode_ctc function

            # Decode the target labels to text
            target_strings = [decode_target(target) for target in targets]  # Process each target sequence

            # Print out the predictions and targets
            for pred, target in zip(decoded_texts, target_strings):
                print(f"Predicted: {pred}")
                print(f"Ground Truth: {target}")
                print("-" * 50)
                process_transcription_and_save_separately(pred, output_file)

            # Use WER metric (works with strings now)
            wer = wer_metric(decoded_texts, target_strings)
            print(f"WER: {wer.item():.2f}")

# Assuming you have a model, test loader, vocab, char_to_index, and index_to_char
evaluate(ocr_model, test_loader, vocab, char_to_index, index_to_char)  # This would call the evaluate function with your OCR model and test loader
# Out:
# Predicted: tensor([2,
# Ground Truth: 277-21 Y-o-u|a-r-e|h-e-r-e-b-y|o-r-d-e-r-e-d-s_cm|a-s|s-o-o-n|a-s
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 277-32 o-r|a-n-y|o-t-h-e-r-s-s_cm|s_mi|o-r|P-l-a-n-t-a-t-i-o-n-s-s_pt|s_mi|L-i-e-u-t-e-n-a-n-t|F-r-a-s_mi
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 276-07 h-a-v-e|C-a-t-t-l-e|d-e-l-i-v-e-r-e-d|h-e-r-e|s_et-c-s_pt|b-y|t-h-e|s_1st-s_pt|o-f|n-e-x-t
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 273-25 t-h-e|m-e-n|c-o-m-p-l-e-t-e-l-y|f-u-r-n-i-s-h-e-d|w-i-t-h|b-o-t-h-s_sq|a-n-d
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 302-04 s-m-a-l-l|d-u-r-a-t-i-o-n-s_pt|W-e|s-h-a-l-l|a-l-s-o|i-n|a|l-i-t-t-l-e|t-i-m-e-s_cm
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 274-15 h-i-m|i-m-m-e-d-i-a-t-e-l-y-s_pt|I-f|n-o|o-t-h-e-r|H-o-r-s-e-s-s_cm|b-e-l-o-n-g-s_mi
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 303-31 o-f|t-h-e-m|a-r-e|a-c-q-u-a-i-n-t-e-d|t-h-a-t|s-u-c-h|a|L-a-w|e-x-i-s-t-s-s_qo|a-n-d
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 275-28 o-f|P-o-r-k|a-s|y-o-u|i-m-a-g-i-n-e|w-i-l-l|b-e|n-e-c-e-s_s-s-a-r-y|f-o-r|t-h-e
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 278-10 N-o-v-e-m-b-e-r|s_1st-s_pt|s_1-s_7-s_5-s_5-s_pt
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 308-10 o-f|C-l-o-t-h-e-s-s_sq|S-h-o-e-s-s_cm|S-t-o-c-k-i-n-g-s_cm|S-h-i-r-t-s-s_cm|s_et-c-s_pt|p-r-o-p-o-r-t-i-o-n-a-s_mi
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 308-28 S-t-o-r-e-s|a-n-d|m-e-d-i-c-i-n-e-s|a-r-r-i-v-e-s-s_cm|y-o-u|a-r-e|t-o|e-m-b-r-a-c-e
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 278-14 t-h-e|s_1st-s_pt|o-f|D-e-c-e-m-b-e-r-s_cm|t-o|R-e-n-d-e-z-v-o-u-s|a-t|A-l-e-x-s_mi
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([1,
# Ground Truth: 277-20 V-i-r-g-i-n-i-a|R-e-g-i-m-e-n-t-s_pt
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 275-32 i-n|y-o-u-r|h-a-n-d-s-s_cm|w-h-a-t-e-v-e-r|D-r-a-u-g-h-t-s|C-a-p-t-a-i-n|H-o-g-g
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 275-08 a-w-k-w-a-r-d-s_cm|p-a-r-t-i-c-u-l-a-r|p-a-i-n-s|m-u-s-t|b-e|t-a-k-e-n|w-i-t-h
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 308-16 c-o-n-v-e-n-i-e-n-t-l-y|Q-u-a-r-t-e-r-e-d|o-n|t-h-e-i-r|m-a-r-c-h|u-p-s_sq|t-h-e-r-e
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# WER: 1.00
# Predicted: tensor([2, ,
# Ground Truth: 309-29 m-e-n|i-n|t-h-i-s|t-o-w-n|s_mi|a-n-d|a-l-l|c-o-n-t-i-n-g-e-n-c-e-s-s_pt
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 309-24 d-r-i-l-l|t-h-e|R-e-c-r-u-i-t-s-s_cm|a-t|l-e-a-s-t|t-w-i-c-e|a-s_mi-d-a-y-s_pt
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 304-33 m-e|m-u-c-h|c-o-n-c-e-r-n-s_sq|f-e-a-r-i-n-g|t-h-a-t|t-h-i-s|d-e-s_mi
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 271-36 b-o-r-e|a|C-o-m-m-i-s_s-s-i-o-n-s_pt
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 303-17 a-r-t-s|i-s|e-n-c-r-e-a-s-e-d-s_cm|I|s-u-p-p-o-s-e|a-l-l|t-h-e|O-f-f-i-c-e-r-s|b-e-l-o-n-g-i-n-g
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([, , ,
# Ground Truth: 309-12 I|a-m|s_et-c-s_pt
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 300-07 i-n-g|t-h-a-t|t-h-e-r-e|i-s|n-o|d-i-s-a-g-r-e-e-m-e-n-t|b-e-t-w-e-e-n
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 278-30 t-i-o-n|m-a-d-e|b-e-t-w-e-e-n|t-h-e-m|a-n-d|S-e-r-g-e-a-n-t-s-s_cm
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 275-15 s-t-r-u-c-t-i-o-n-s|w-h-i-c-h|I|l-e-f-t|w-i-t-h|h-i-m-s_cm|a-n-d|s-e-e
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 302-16 i-n|M-a-r-y-l-a-n-d|o-r|P-e-n-n-s-y-l-v-a-n-i-a-s_cm|w-h-e-n|t-h-e-y
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 272-15 A-r-m-s|a-n-d|C-l-o-t-h-i-n-g|t-o|c-o-m-p-l-e-t-e|y-o-u-r|C-o-m-p-a-s_mi
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 271-34 y-o-u-r-s-e-l-f|s_bl-o-r|a-t|l-e-a-s-t|o-u-g-h-t|t-o|b-e-s_br|t-h-a-t|y-o-u-r|C-r-i-m-e
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 274-28 C-a-p-t-a-i-n|A-s-h-b-y-s_qt-s|C-o-m-p-a-n-y|a-s|y-o-u|p-a-s_s-s
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 304-14 c-o-m-p-t-s|w-i-t-h|t-h-e|C-o-m-m-i-t-t-e-e-s_sq|i-s|o-r-d-e-r-e-d|t-o
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 303-29 h-a-v-e|a|v-e-r-y|g-o-o-d|e-f-f-e-c-t-s_pt|T-h-e|C-o-m-m-o-n-a-l-t-y|i-n|g-e-n-e-s_mi
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 300-19 r-e-r|f-o-r|t-h-e|b-a-l-a-n-c-e|o-f|t-h-a-t|t-e-n|t-h-o-u-s-a-n-d
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# WER: 1.03
# Predicted: tensor([2, ,
# Ground Truth: 270-20 c-e-m-b-e-r-s_sq|a-t|w-h-i-c-h|t-i-m-e|i-f|t-h-e-y|d-o|n-o-t
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 271-19 r-e-c-e-i-v-e|C-l-o-t-h-e-s|a-n-d|A-r-m-s|f-o-r|t-h-e|M-e-n-s_pt
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 303-22 p-l-y-s_cm|i-f|h-e|h-a-d|a-n-y|s-u-c-h|t-h-o-u-g-h-t-s-s_pt|I|b-e-l-i-e-v-e-s_cm|o-n
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([1, , , , , ,
# Ground Truth: 307-32 p-a-r-t-i-e-s|a-f-t-e-r|t-h-e-m-s_pt
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 278-27 f-r-o-m|h-e-n-c-e-s_pt|T-h-e|R-e-c-r-u-i-t-s|a-t|F-o-r-t
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 306-16 t-h-e|s_2-s_5th-s_pt|I-n-s-t-a-n-t-s_cm|m-u-s-t|i-m-m-e-d-i-a-t-e-l-y|p-r-o-c-e-e-d
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 270-28 o-f|m-e-n|h-e|h-a-s|e-n-l-i-s-t-e-d-s_pt|s_mi|O-n-e|S-u-b-a-l-t-e-r-n-s_cm
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, , ,
# Ground Truth: 305-01 p-s_pt-s_3-s_0-s_5
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 272-11 o-r-d-e-r-e-d|t-o|h-a-l-t|h-e-r-e-s_cm|w-h-e-r-e|h-e|n-o-w|r-e-m-a-i-n-s
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 270-32 a-t|t-e-n|o-s_qt-c-l-o-c-k-s_pt|s_mi-s_pt|A-l-l|R-e-p-o-r-t-s|a-n-d|R-e-t-u-r-n-s
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 271-16 b-e-f-o-r-e|S-e-r-g-e-a-n-t|W-i-l-p-e-r|a-n-d|h-i-s|P-a-r-t-y-s_cm|y-o-u|a-r-e|t-o
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 305-19 m-e-n-t-s_sq|a-n-d|t-h-e|c-h-i-e-f|o-f|t-h-e-m|a-r-e|t-o-o|p-o-o-r|t-o
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 274-25 m-e-d-i-a-t-e-l-y|t-o|w-o-r-k-s_pt|Y-o-u|a-r-e|t-o|r-e-c-e-i-v-e
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 272-28 s-u-f-f-i-c-e|f-o-r|y-o-u-r|o-w-n|C-o-m-p-a-n-y-s_pt|I|s-h-a-l-l
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 301-06 s-h-a-l-l|n-o-t|k-n-o-w|h-o-w|t-o|a-c-t-s_sq|f-o-r|I|c-a-n|n-e-v-e-r
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 275-07 g-e-t-s-s_sq|a-n-d|i-f|t-h-e-r-e|a-r-e|a-n-y|w-h-o|a-r-e|r-e-m-a-r-k-a-b-l-y
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# WER: 1.16
# Predicted: tensor([2, ,
# Ground Truth: 277-26 t-o|r-e-i-n-f-o-r-c-e|t-h-e|G-a-r-r-i-s-o-n-s_pt|s_mi|W-h-e-n|y-o-u|a-r-r-i-v-e|a-t
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([, , ,
# Ground Truth: 276-11 G-i-v-e-n|s_et-c-s_pt
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 303-07 f-o-r-e|t-h-i-n-k|i-t|a-d-v-i-s-a-b-l-e|t-o|i-n-f-o-r-m|y-o-u-r|H-o-n-o-u-r
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 305-02 L-e-t-t-e-r-s|O-r-d-e-r-s|a-n-d|I-n-s-t-r-u-c-t-i-o-n-s-s_pt|D-e-c-e-m-b-e-r|s_1-s_7-s_5-s_5-s_pt
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 301-10 s_et-c-s_pt|T-h-e|C-o-u-n-t-r-y|h-a-s|s-u-s-t-a-i-n-e-d|i-n-c-o-n-c-e-i-v-a-b-l-e
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 272-04 s_2-s_8th-s_pt|T-o|C-a-p-t-a-i-n|P-e-t-e-r|H-o-g-g-s_cm|o-f|t-h-e|V-i-r-g-i-n-i-a
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 273-17 t-o|c-a-r-r-y|o-n|t-h-e|u-n-d-e-r-t-a-k-i-n-g|w-i-t-h|v-i-g-o-u-r-s_pt
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 275-10 o-r-d-e-r|a-n-d|d-i-s-c-i-p-l-i-n-e-s_cm|a-n-d|s-e-e|t-h-a-t|n-o|i-r-r-e-g-u-s_mi
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 308-08 c-h-e-s-t-e-r-s_sq|w-h-i-t-h-e-r|t-h-e-y|a-r-e|t-o|b-e|s-e-n-t-s_cm|u-n-d-e-r|t-h-e
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([1, , ,
# Ground Truth: 275-19 s_2-s_9th-s_pt|s_1-s_7-s_5-s_5-s_pt
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 273-26 m-a-r-c-h|t-h-e-m|i-m-m-e-d-i-a-t-e-l-y|t-o|F-o-r-t|C-u-m-b-e-r-l-a-n-d-s_sq
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 304-14 c-o-m-p-t-s|w-i-t-h|t-h-e|C-o-m-m-i-t-t-e-e-s_sq|i-s|o-r-d-e-r-e-d|t-o
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([1, , , ,
# Ground Truth: 309-05 D-e-c-e-m-b-e-r|s_1-s_6th-s_pt|s_1-s_7-s_5-s_5-s_pt
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 277-24 w-i-t-h|b-o-t-h-s_sq|a-n-d|m-a-r-c-h|t-h-e-m|i-m-m-e-d-i-a-t-e-l-y
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 300-08 t-h-e|R-e-t-u-r-n-s-s_cm|a-n-d|y-o-u-r|P-a-y-s_mi-R-o-l-l-s-s_sq|a-s|t-h-e-r-e
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 306-15 a-r-r-i-v-e|a-t|F-r-e-d-e-r-i-c-k-s-b-u-r-g-h-s_cm|b-e-t-w-e-e-n|t-h-i-s|a-n-d
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# WER: 1.12
# Predicted: tensor([2, ,
# Ground Truth: 271-19 r-e-c-e-i-v-e|C-l-o-t-h-e-s|a-n-d|A-r-m-s|f-o-r|t-h-e|M-e-n-s_pt
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 271-21 s_2-s_8th-s_pt|T-o|C-a-p-t-a-i-n|B-e-l-l|o-f|t-h-e|V-i-r-g-i-n-i-a|R-e-g-i-m-e-n-t-s_pt
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([, ,
# Ground Truth: 271-06 C-a-p-t-a-i-n|H-o-g-g-s_qt-s|C-o-m-p-a-n-y|a-t|F-o-r-t|D-i-n-w-i-d-d-i-e
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 307-20 G-i-v-e-n|a-t|A-l-e-x-a-n-d-r-i-a-s_cm|s_et-c-s_pt|D-e-c-e-m-b-e-r
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 275-35 e-n-g-a-g-e-d|t-o|m-a-k-e|B-e-r-r-e-l-s|f-o-r|t-h-e|P-r-o-v-i-s-i-o-n-s-s_cm|a-n-d|t-o
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 308-13 T-h-i-n-g-s|d-e-l-i-v-e-r-e-d|i-n-t-o|t-h-e|w-a-g-g-o-n-s-s_cm|a-n-d|s-e-e|t-h-a-t
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 303-09 I|f-o-r-g-o-t|t-o|m-e-n-t-i-o-n|w-h-e-n|I|w-a-s|d-o-w-n-s_cm|t-h-a-t|M-r-s_pt|L-i-v-i-n-g-s_mi
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 274-34 t-o|b-e|s-e-n-t|f-r-o-m|t-h-i-s|p-l-a-c-e|w-i-t-h|S-e-r-g-e-a-n-t
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 279-01 L-e-t-t-e-r-s-s_cm|O-r-d-e-r-s|a-n-d|I-n-s-t-r-u-c-t-i-o-n-s-s_pt|N-o-v-e-m-b-e-r|s_1-s_7-s_5-s_5-s_pt-s_2-s_7-s_9-s_pt
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 275-25 t-o|s-e-n-d|u-p|D-o-c-t-o-r|W-a-l-k-e-r-s_cm|o-r|g-o|y-o-u-r-s-e-l-f|t-h-e-r-e-s_cm|t-o
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 276-22 L-i-e-u-t-e-n-a-n-t|H-a-l-l|a-n-d|E-n-s-i-g-n|P-r-i-c-e-s_sq|w-h-o|a-r-e
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 300-18 s-e-t-t-l-e|w-i-t-h|t-h-e|C-o-m-m-i-t-t-e-e|t-o|t-h-e|T-r-e-a-s-u-s_mi
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 272-12 u-n-f-i-t|f-o-r|D-u-t-y-s_qo|t-h-e-r-e-f-o-r-e|I|h-a-v-e|s-e-n-t
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 303-08 o-f|i-t-s_cm|h-o-p-i-n-g|t-h-a-t|i-t|w-i-l-l|c-o-r-r-e-s-p-o-n-d|w-i-t-h|y-o-u-r|o-w-n|o-p-i-n-i-o-n-s_pt
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 272-30 f-o-r|y-o-u-r|u-s-e|w-h-e-n|I|s-e-e|h-i-m-s_pt|Y-o-u|a-r-e|t-o
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([,
# Ground Truth: 306-35 A-l-e-x-a-n-d-r-i-a-s_qo|D-e-c-e-m-b-e-r|s_8th-s_pt|s_1-s_7-s_5-s_5-s_pt
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# WER: 1.00
# Predicted: tensor([2, ,
# Ground Truth: 275-18 W-i-n-c-h-e-s-t-e-r-s_cm|O-c-t-o-b-e-r|s_GW
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 274-17 o-f|t-h-e|C-o-u-n-t-r-y|T-e-a-m-s|m-u-s-t|b-e|s-t-o-p-p-e-d-s_cm
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 302-10 n-o-t-h-i-n-g|e-l-s-e-s_pt|I|s-h-o-u-l-d|b-e|g-l-a-d|y-o-u-r|H-o-n-o-r
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 276-22 L-i-e-u-t-e-n-a-n-t|H-a-l-l|a-n-d|E-n-s-i-g-n|P-r-i-c-e-s_sq|w-h-o|a-r-e
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([,
# Ground Truth: 275-16 t-h-a-t|t-h-e-y|a-r-e|o-b-s-e-r-v-e-d-s_pt
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 274-24 S-o-l-d-i-e-r-s|a-r-e|C-o-o-p-e-r-s-s_cm|t-h-e-y|m-u-s-t|b-e|s-e-t|i-m-s_mi
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 276-27 u-n-t-i-l|f-u-r-t-h-e-r|o-r-d-e-r-s-s_mi|L-i-e-u-t-e-n-a-n-t|E-u-s-t-a-c-e-s_cm|a-n-d
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 272-18 d-e-r-e-d|E-n-s-i-g-n|F-l-e-m-i-n-g-s_cm|w-i-t-h|e-i-g-h-t|o-t-h-e-r-s-s_cm|t-o
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 307-16 o-r|i-d-l-e|t-h-e-i-r|t-i-m-e-s_sq|b-u-t|m-a-k-e|t-h-e|u-t-m-o-s-t|d-i-s-p-a-t-c-h|t-o
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 271-27 Y-o-u|a-r-e|h-e-r-e-b-y|o-r-d-e-r-e-d-s_cm|p-e-r-e-m-p-t-o-r-i-l-y-s_cm|t-o|b-e|a-t
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([1,
# Ground Truth: 275-17 G-i-v-e-n|u-n-d-e-r|m-y|H-a-n-d|s_et-c-s_pt
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 303-28 p-e-o-p-l-e|w-e-r-e|m-a-d-e|a-c-q-u-a-i-n-t-e-d|w-i-t-h|t-h-e|L-a-w-s_cm|i-t|w-o-u-l-d
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 271-35 i-s|s-u-f-f-i-c-i-e-n-t|t-o|B-r-e-a-k|t-h-e|b-e-s-t|O-f-f-i-c-e-r|t-h-a-t|e-v-e-r
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 273-32 t-h-e|C-o-m-p-a-n-i-e-s|a-t|F-o-r-t|C-u-m-b-e-r-l-a-n-d-s_cm|y-o-u|a-r-e
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 275-12 a-l-l-o-w-e-d|t-o|p-i-l-l-a-g-e|t-h-e|C-o-u-n-t-r-y-s_cm|w-h-i-c-h|w-a-s|v-e-r-y
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 306-12 r-e-m-a-i-n|i-n|F-r-e-d-e-r-i-c-k-s-b-u-r-g-h|a-n-d|F-a-l-m-o-u-t-h-s_cm
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# WER: 1.00
# Predicted: tensor([2, ,
# Ground Truth: 270-21 p-u-n-c-t-u-a-l-l-y|a-p-p-e-a-r|a-t|t-h-e|p-l-a-c-e|o-f|R-e-n-d-e-z-s_mi
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([, , , ,
# Ground Truth: 272-06 S-i-r-s_cm
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 275-29 T-r-o-o-p-s-s_cm|u-p-o-n|t-h-e|m-o-s-t|r-e-a-s-o-n-a-b-l-e|t-e-r-m-s|y-o-u|c-a-n-s_sq|a-n-d
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 302-29 k-n-o-w-s_cm|w-h-e-t-h-e-r|y-o-u|w-o-u-l-d|h-a-v-e|m-o-r-e|l-a-i-d|i-n
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 301-18 t-h-a-t|B-i-l-l-s_cm|w-h-i-c-h|i-f|y-o-u|a-r-e|n-o-t|k-i-n-d|e-n-o-u-g-h
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 302-15 m-i-g-h-t|o-f-t-e-n|g-e-t|n-e-c-e-s_s-s-a-r-i-e-s|f-o-r|t-h-e|R-e-g-i-m-e-n-t
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 305-14 M-a-r-y-l-a-n-d-s_cm|a-s|w-e-l-l|a-s|t-h-i-s|p-a-r-t|o-f|V-i-r-g-i-n-i-a-s_cm|a-n-d
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 270-25 a-t|o-n-e|o-f|t-h-e|C-l-o-c-k-s_cm|t-o|r-e-c-e-i-v-e|t-h-e-i-r|R-e-c-r-u-i-s_mi
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 307-31 m-e-d-i-a-t-e-l-y|a-d-v-e-r-t-i-s-i-n-g-s_cm|a-n-d|s-e-n-d-i-n-g|a|p-a-r-t-y|o-r
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 271-13 f-e-r-e-d-s_pt|Y-o-u|a-r-e|t-o|a-c-c-o-u-n-t|w-i-t-h|C-a-p-t-a-i-n|B-e-l-l
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 271-17 h-a-l-t|t-h-e-r-e|u-n-t-i-l|h-e|j-o-i-n-s-s_cm|i-n|o-r-d-e-r|t-o|e-s-c-o-r-t|t-h-e
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 302-17 c-a-n|n-o-t|b-e|h-a-d|h-e-r-e-s_pt|b-u-t|w-i-t-h|o-u-r|m-o-n-e-y
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 277-10 t-o|k-e-e-p|f-o-r|t-h-a-t|p-u-r-p-o-s-e-s_pt|E-v-e-r-y|O-f-f-i-c-e-r|i-s|t-o|p-r-o-v-i-d-e|a-n
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 301-25 p-o-s_s-s-i-b-l-e|s_bl-I|m-e-a-n|w-h-i-l-e|w-e|a-r-e|o-n|o-u-r|m-a-r-c-h-s_sq
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 305-11 C-o-u-n-t-r-y-s_pt|T-h-o-s-e|w-h-i-c-h|C-a-r-l-y-l-e|a-n-d|D-a-l-t-o-n|c-o-n-s_mi
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 303-36 t-e-d-s_cm|t-h-a-t|w-o-u-l-d|n-o-w|g-l-a-d-l-y|r-e-t-u-r-n|i-f|t-h-e-y|c-o-u-l-d
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# WER: 1.06
# Predicted: tensor([2, ,
# Ground Truth: 276-29 t-h-e-y|a-r-r-i-v-e|a-t|F-o-r-t|C-u-m-b-e-r-l-a-n-d-s_br|t-h-e|C-o-m-p-a-n-y
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 275-23 g-i-v-e|s-u-c-h|d-i-r-e-c-t-i-o-n-s|a-s|y-o-u|s-h-a-l-l|s-e-e|n-e-c-e-s_s-s-a-r-y|a-b-o-u-t
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 308-20 t-o|s-e-n-d|a|S-e-r-g-e-a-n-t-s_cm|a-n-d|o-n-e|o-r|t-w-o|t-r-u-s-t-y|m-e-n
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 271-05 Y-o-u|a-r-e|h-e-r-e-b-y|o-r-d-e-r-e-d|t-o|r-e-p-a-i-r|t-o
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 301-22 q-u-a-i-n-t-e-d|w-i-t-h|t-h-e|p-r-o-c-e-e-d-i-n-g-s|o-f|t-h-e|C-o-u-r-t-s_pt
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 306-07 t-h-i-s-s_cm|y-o-u|m-u-s-t|h-i-r-e|a-n-d|i-m-p-r-e-s_s-s|w-a-g-g-o-n-s-s_qo
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([1, , , , , ,
# Ground Truth: 308-21 i-n|p-u-r-s-u-i-t|o-f|t-h-e-m-s_pt
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 309-10 h-e-r-e-o-f-s_cm|t-o|r-e-p-a-i-r|t-o|W-i-n-c-h-e-s-t-e-r-s_cm|w-h-e-r-e|y-o-u|w-i-l-l|m-e-e-t
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 270-24 T-h-e-y|a-r-e|t-o|w-a-i-t|u-p-o-n|t-h-e|A-i-d|d-e|c-a-m-p
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 300-27 h-e-r-e|t-o|e-n-g-a-g-e|m-o-r-e-s_sq|s_mi|t-o|r-e-c-e-i-v-e|t-h-e|R-e-c-r-u-i-t-s
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 309-33 u-p|t-h-e|C-a-s-k|o-f|T-o-o-l-s|b-y|t-h-e|f-i-r-s-t|w-a-g-g-o-n|t-h-a-t
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 304-06 w-o-u-l-d|b-e|o-f|s-e-r-v-i-c-e|t-o|u-s-s_qo|w-i-t-h-o-u-t|l-e-a-v-e|w-e
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 304-16 t-h-o-u-s-a-n-d|p-o-u-n-d-s-s_cm|w-h-i-c-h|I|b-e-l-i-e-v-e|w-e|s-h-a-l-l
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([1, , , ,
# Ground Truth: 272-05 R-e-g-i-m-e-n-t-s_pt
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 302-11 w-o-u-l-d|d-i-r-e-c-t|w-h-a-t|i-s|t-o|b-e|d-o-n-e|i-n|t-h-e-s-e|c-a-s_mi
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 305-21 t-o|m-y|F-r-i-e-n-d-s|b-e-l-o-w-s_sq|a-n-d|b-e-l-i-e-v-e|m-e|s_et-c-s_pt
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# WER: 1.19
# Predicted: tensor([, ,
# Ground Truth: 308-27 S-o|s-o-o-n|a-s|t-h-e|V-e-s_s-s-e-l|w-i-t-h|t-h-e
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 306-14 A-l-l|t-h-e|R-e-c-r-u-i-t-s|w-h-i-c-h|n-o-w|a-r-e-s_cm|a-n-d|s-h-a-l-l
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 303-36 t-e-d-s_cm|t-h-a-t|w-o-u-l-d|n-o-w|g-l-a-d-l-y|r-e-t-u-r-n|i-f|t-h-e-y|c-o-u-l-d
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 276-08 m-o-n-t-h-s_cm|s_mi|I|d-e-s-i-r-e|t-h-a-t|f-o-r|s-u-c-h|a-s|y-o-u|r-e-c-e-i-v-e|u-p-s_mi
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 271-13 f-e-r-e-d-s_pt|Y-o-u|a-r-e|t-o|a-c-c-o-u-n-t|w-i-t-h|C-a-p-t-a-i-n|B-e-l-l
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 272-14 f-r-o-m|F-o-r-t|C-u-m-b-e-r-l-a-n-d|a-n-d|t-h-i-s|p-l-a-c-e
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 278-07 D-e-c-e-m-b-e-r-s_cm|w-i-t-h|a-l-l|t-h-e|m-e-n|y-o-u|c-a-n
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 309-35 e-d|u-n-f-i-t|f-o-r|D-u-t-y-s_cm|o-n|R-e-v-i-e-w-s_sq|a-r-e|o-r-d-e-r-e-d|t-o|b-e
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 276-13 s_2-s_9th-s_pt|s_1-s_7-s_5-s_5
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 273-30 g-o-n-s-s_cm|w-h-i-c-h|m-u-s-t|a-l-s-o|b-e|l-o-a-d-e-d|u-p|w-i-t-h|S-a-l-t-s_pt
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 309-02 L-e-t-t-e-r-s|O-r-d-e-r-s|a-n-d|I-n-s-t-r-u-c-t-i-o-n-s|D-e-c-e-m-b-e-r|s_1-s_7-s_5-s_5-s_pt
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 276-32 t-u-r-n|t-o|t-h-e-i-r|r-e-s-p-e-c-t-i-v-e|C-o-m-p-a-n-i-e-s-s_cm|s-o|s-o-o-n|a-s
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 304-28 s-e-l|l-e-f-t|W-i-l-l-i-a-m-s-b-u-r-g-h|t-w-o|d-a-y-s|a-f-t-e-r|I|d-i-d-s_cm
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 304-30 p-r-e-s_s-s|r-e-t-u-r-n-e-d-s_cm|w-h-i-c-h|t-h-e|G-o-v-e-r-n-o-r|s-e-n-t|t-o
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 275-05 c-i-s-e-d|a-s|o-f-t-e-n|e-v-e-r-y|d-a-y|a-s|t-h-e|d-u-t-y|w-i-l-l|a-d-m-i-t-s_sq
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 303-19 t-e-d|a-l-s-o-s_pt|C-o-l-o-n-e-l|S-t-e-p-h-e-n-s-s_cm|i-n|a|l-a-t-e|l-e-t-t-e-r-s_cm|d-i-s-s_mi
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# WER: 1.00
# Predicted: tensor([2, ,
# Ground Truth: 278-18 A-s|C-o-l-o-n-e-l|S-t-e-p-h-e-n|h-a-s|b-r-o-u-g-h-t
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 302-21 f-o-r|R-e-n-d-e-z-v-o-u-s-i-n-g|a-t|t-h-i-s|p-l-a-c-e-s_cm|t-h-e-r-e|c-a-m-e|i-n
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 307-31 m-e-d-i-a-t-e-l-y|a-d-v-e-r-t-i-s-i-n-g-s_cm|a-n-d|s-e-n-d-i-n-g|a|p-a-r-t-y|o-r
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 302-18 i-t|i-s|i-s|i-m-p-o-s_s-s-i-b-l-e-s_sq|o-u-r|p-a-p-e-r|n-o-t|p-a-s_s-s-i-n-g|t-h-e-r-e-s_pt
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 301-32 t-h-e|B-i-l-l|w-o-u-l-d|b-e|r-e-m-o-v-e-d-s_cm|b-y|y-o-u-r|H-o-n-s_mi
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 308-06 a-r-e-s_cm|w-i-t-h|a-l-l|p-o-s_s-s-i-b-l-e|d-i-s-p-a-t-h-s_cm|t-o|p-r-o-c-u-r-e|a|s-u-f-s_mi
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 309-23 a-n-t-s|w-h-o|u-n-d-e-r-s-t-a-n-d|t-h-e|m-a-n-u-a-l|E-x-e-r-c-i-s-e-s_cm|d-o
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 276-18 C-o-r-p-o-r-a-l-s_cm|o-n-e|D-r-u-m-m-e-r|a-n-d|t-w-e-n-t-y|f-i-v-e|p-r-i-v-a-t-e
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([1, , ,
# Ground Truth: 279-33 R-e-g-i-m-e-n-t-s_pt
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 306-07 t-h-i-s-s_cm|y-o-u|m-u-s-t|h-i-r-e|a-n-d|i-m-p-r-e-s_s-s|w-a-g-g-o-n-s-s_qo
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 274-20 t-h-e|C-a-t-t-l-e-s_cm|u-n-t-i-l|t-h-e-y|h-e-a-r|f-r-o-m|t-h-e|C-o-m-s_mi
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 302-32 A-s|I|c-a-n|n-o-t|n-o-w|c-o-n-c-e-i-v-e-s_cm|t-h-a-t
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 308-07 f-i-c-i-e-n-t|n-u-m-b-e-r|o-f|w-a-g-g-o-n-s|t-o|c-a-r-r-y|t-h-e-m|t-o|W-i-n-s_mi
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 301-27 t-i-e-s|c-a-n|p-a-s_s-s|w-i-t-h|s-a-f-e-t-y-s_qo|a-t|a-l-l|t-i-m-e-s|i-t|m-u-s-t|b-e
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 306-18 N-s_qo-B-s_pt|E-n-q-u-i-r-e|o-f|M-r-s_pt|D-i-c-k|a-n-d|o-t-h-e-r|M-e-r-s_mi
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 300-02 s_3-s_0-s_0-s_pt|L-e-t-t-e-r-s-s_cm|O-r-d-e-r-s|a-n-d|I-n-s-t-r-u-c-t-i-o-n-s-s_pt|D-e-c-e-m-b-e-r|s_1-s_7-s_5-s_5-s_pt
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# WER: 1.03
# Predicted: tensor([2, ,
# Ground Truth: 301-20 t-i-o-n|o-f|i-t-s_qo|i-s_pt-e-s_pt|d-e-l-a-y-i-n-g|t-h-e|e-x-e-c-u-t-i-o-n|o-f|S-e-n-s_mi
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 272-19 j-o-i-n|y-o-u-s_sq|h-e|b-e-i-n-g|a|S-u-r-g-e-o-n-s_cm|h-e|i-s|d-e-s-i-r-e-d|t-o
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 274-35 W-i-l-p-e-r-s_cm|i-n|t-h-e|r-o-o-m|o-f|D-u-n-c-a-n|F-e-r-g-u-s-o-n-s_cm
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 273-06 R-e-c-r-u-i-t|o-t-h-e-r-s-s_cm|k-e-e-p-i-n-g|y-o-u-r|C-o-m-p-a-n-y|t-o|t-h-e|E-s-t-a-s_mi
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 275-11 l-a-r-i-t-i-e-s|h-a-p-p-e-n-s_sq|a-n-d|t-h-a-t|t-h-e|m-e-n|a-r-e|n-o-t
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 279-05 t-h-i-s|i-s|t-o|b-e|p-a-i-d|t-o|t-h-e|S-u-r-g-e-o-n|Q-u-a-r-t-e-r-l-y-s_pt|T-h-e-r-e|i-s
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 276-17 O-n-e|S-u-b-a-l-t-e-r-n-s_cm|o-n-e|S-e-r-g-e-a-n-t-s_cm|o-n-e
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 277-22 t-h-e|C-l-o-t-h-e-s|a-n-d|A-r-m-s|a-r-r-i-v-e-s_cm|t-o|f-u-r-n-i-s-h|a-l-l|t-h-e
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 275-13 m-u-c-h|c-o-m-p-l-a-i-n-e-d|o-f|i-n|t-h-e|l-a-s-t|D-e-t-a-c-h-m-e-n-t-s_pt
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, , ,
# Ground Truth: 306-26 Y-o-u|a-r-e|h-e-r-e-b-y|r-e-q-u-i-r-e-d|t-o|t-a-k-e
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 273-22 Y-o-u|a-r-e|h-e-r-e-b-y|O-r-d-e-r-e-d-s_cm|s-o|s-o-o-n|a-s
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 303-10 s-t-o-n-s_cm|t-h-e|F-o-r-t|s_mi|M-a-j-o-r-s_cm|w-a-s|a-p-p-o-i-n-t-e-d|a-d-j-u-t-a-n-t|t-o|o-u-r
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 276-18 C-o-r-p-o-r-a-l-s_cm|o-n-e|D-r-u-m-m-e-r|a-n-d|t-w-e-n-t-y|f-i-v-e|p-r-i-v-a-t-e
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([,
# Ground Truth: 279-30 l-i-v-e-r|t-w-e-n-t-y|B-l-a-n-k-e-t-s-s_pt
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 309-21 O-f-f-i-c-e-r-s|w-h-o|e-n-l-i-s-t-e-d|t-h-e-m-s_sq|m-e-n-t-i-o-n-i-n-g|t-h-e-i-r|h-e-i-g-h-t-s_cm
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 272-02 s_2-s_7-s_2-s_pt|L-e-t-t-e-r-s-s_cm|O-r-d-e-r-s|a-n-d|I-n-s-t-r-u-c-t-i-o-n-s-s_pt|O-c-t-o-b-e-r
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# WER: 1.03
# Predicted: tensor([2, ,
# Ground Truth: 273-11 S-i-r-s_cm
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([, ,
# Ground Truth: 277-20 V-i-r-g-i-n-i-a|R-e-g-i-m-e-n-t-s_pt
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 308-06 a-r-e-s_cm|w-i-t-h|a-l-l|p-o-s_s-s-i-b-l-e|d-i-s-p-a-t-h-s_cm|t-o|p-r-o-c-u-r-e|a|s-u-f-s_mi
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 304-21 t-e-r-s_sq|b-u-t|m-e-e-t-i-n-g|w-i-t-h|L-e-t-t-e-r-s|a-t|F-r-e-d-e-r-i-c-k-s-s_mi
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 270-11 C-o-c-k-e-s-s_qt|C-o-m-p-a-n-y-s_cm|a-t|N-i-c-h-o-l-a-s|R-e-a-s-m-e-r-s-s_pt
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 304-35 k-n-o-w|h-o-w|t-o|a-c-t-s_sq|s_mi|i-t|w-i-l-l|b-e|u-s-e-l-e-s_s-s|f-o-r|m-e
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 308-04 t-h-e|S-t-o-r-e-s-s_cm|s_et-c-s_pt|a-n-d|t-o|b-e|u-n-d-e-r|t-h-e|s-a-m-e|d-i-r-e-c-t-i-o-n-s
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 277-27 W-i-n-c-h-e-s-t-e-r-s_cm|y-o-u|m-u-s-t|p-r-o-v-i-d-e|y-o-u-r|m-e-n|w-i-t-h|C-a-r-s_mi
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([,
# Ground Truth: 276-16 P-a-r-o-l-e|W-i-l-l-i-a-m-s-b-u-r-g-h-s_pt
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 270-10 P-l-a-n-t-a-t-i-o-n|o-f|C-h-a-r-l-e-s|S-e-l-l-a-r-s|s_mi|t-h-e|r-e-s-t|t-o|C-a-p-t-a-i-n
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 305-28 A-l-e-x-a-n-d-r-i-a|D-e-c-e-m-b-e-r|s_5th-s_pt|s_1-s_7-s_5-s_5-s_pt
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 305-06 o-t-h-e-r|p-r-e-t-e-n-c-e-s_cm|t-h-a-n|t-h-a-t|o-f|h-a-v-i-n-g|a|c-o-m-m-i-s_s-s_mi
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 303-15 s-e-e-m-s|y-e-t|d-o-u-b-t-f-u-l-s_sq|I|s-h-o-u-l-d|b-e|g-l-a-d|i-f|y-o-u-r|H-o-n-o-u-r
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 278-19 s_lb-s_1-s_0-s_0-s_0|w-h-i-c-h|I|w-r-o-t-e|f-o-r|t-o|p-a-y|o-f-f|t-h-e|T-r-o-o-p-s-s_cm
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 305-31 a-t|F-r-e-d-e-r-i-c-k-s-b-u-r-g-h-s_pt
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 300-31 t-h-e|g-r-e-a-t-e-r|d-i-s-p-a-t-c-h-s_pt|T-h-e|V-e-s_s-s-e-l|i-s|n-o-t|y-e-t
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# WER: 1.00
# Predicted: tensor([2, ,
# Ground Truth: 308-28 S-t-o-r-e-s|a-n-d|m-e-d-i-c-i-n-e-s|a-r-r-i-v-e-s-s_cm|y-o-u|a-r-e|t-o|e-m-b-r-a-c-e
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 271-15 I-f|y-o-u|s-h-o-u-l-d|a-r-r-i-v-e|a-t|A-u-g-u-s-t-a|C-o-u-r-t|H-o-u-s-e
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 276-26 L-i-e-u-t-e-n-a-n-t|K-i-n-g-s_cm|a-n-d|b-e|u-n-d-e-r|h-i-s|c-o-m-m-a-n-d
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 303-16 w-o-u-l-d|f-i-x|i-t-s_qo|s-o|i-s|C-a-p-t-a-i-n|S-t-e-w-a-r-t-s-s_qo|I-f|C-a-p-t-a-i-n|S-t-e-w-s_mi
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 275-06 a-n-d|t-h-a-t|t-h-e-y|a-r-e|p-r-a-c-t-i-s-e-d|a-l-s-o|i-n|s-h-o-o-t-i-n-g|a-t|T-a-r-s_mi
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# Predicted: tensor([2, ,
# Ground Truth: 271-08 w-i-t-h-o-u-t|a|S-u-r-g-e-o-n-s_cm|i-f|y-o-u|w-i-l-l|d-o|t-h-a-t|d-u-t-y-s_cm|a-n
# --------------------------------------------------
# All transcriptions saved to /content/drive/My Drive/justresnetall.txt
# WER: 1.00
